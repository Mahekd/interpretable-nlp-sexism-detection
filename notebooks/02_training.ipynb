# %% [markdown]
# # 02 : Training
#
# #Task A
#
# Fine-tunes BERT and RoBERTa on EDOS Task A using `src/train.py`.

# %%
# !git clone https://github.com/Mahekd/interpretable-nlp-sexism-detection.git
# %cd interpretable-nlp-sexism-detection
# !pip install -q -r requirements.txt
# Out:
# Cloning into 'interpretable-nlp-sexism-detection'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 106 (delta 47), reused 66 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (106/106), 6.36 MiB | 16.19 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# /content/interpretable-nlp-sexism-detection/interpretable-nlp-sexism-detection

# %% [markdown]
# ## Hyperparameter sweep (Task A - RoBERTA)

# %% [markdown]
# I am fine-tuning RoBERTA-base for the binary sexism classification task (Task A) using hyperparameters selected via a grid search over learning rate ∈ {2e-5, 3e-5} and batch size ∈ {16, 32}, evaluated on dev-set macro-F1.
#
# The model will be trained for up to 10 epochs with early stopping (monitoring dev macro-F1) to prevent overfitting; the best checkpoint (highest dev macro-F1) is retained for final evaluation. To address class imbalance (10,602 not-sexist vs. 3,398 sexist examples in training), we apply class-weighted cross-entropy loss, with weights computed as the inverse of class frequency (0.660 for not-sexist, 2.060 for sexist), giving the minority (sexist) class proportionally more influence on the loss.

# %%
MODELS = ["roberta-base", "bert-base-uncased"]
LRS = ["2e-5", "3e-5"]
BATCH_SIZES = [16, 32]

for model in MODELS:
    for lr in LRS:
        for bs in BATCH_SIZES:
            run_name = f"lr{lr}_bs{bs}"
            # !python -m src.train --task A --model_name {model} --lr {lr} --batch_size {bs} --run_name {run_name}
# Out:
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 481/481 [00:00<00:00, 2.74MB/s]
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 165kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 22.4MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 23.4MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 34.5MB/s]
# model.safetensors: 100% 499M/499M [00:07<00:00, 62.7MB/s]
# Loading weights: 100% 197/197 [00:00<00:00, 5041.32it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.dense.bias      | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.out_proj.weight | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Epoch 1/10 | train_loss=0.5135 | dev_macro_f1=0.7508
# Writing model shards: 100% 1/1 [00:06<00:00,  6.55s/it]
# Epoch 2/10 | train_loss=0.3673 | dev_macro_f1=0.8144
# Writing model shards: 100% 1/1 [00:11<00:00, 11.27s/it]
# Epoch 3/10 | train_loss=0.2624 | dev_macro_f1=0.8083
# Epoch 4/10 | train_loss=0.2140 | dev_macro_f1=0.8258
# Writing model shards: 100% 1/1 [00:11<00:00, 11.18s/it]
# Epoch 5/10 | train_loss=0.1433 | dev_macro_f1=0.8132
# Epoch 6/10 | train_loss=0.0844 | dev_macro_f1=0.8252
# Epoch 7/10 | train_loss=0.0517 | dev_macro_f1=0.8255
# Early stopping at epoch 7 (best dev macro-F1=0.8258 @ epoch 4)
#
# Loading best checkpoint (dev macro-F1=0.8258) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 4895.76it/s]
# Test macro-F1: 0.8231
#
#               precision    recall  f1-score   support
#
#   not sexist      0.919     0.906     0.912      3030
#       sexist      0.718     0.751     0.734       970
#
#     accuracy                          0.868      4000
#    macro avg      0.818     0.828     0.823      4000
# weighted avg      0.870     0.868     0.869      4000
#
# Saved results to outputs/best_model_taskA_roberta-base_lr2e-5_bs16/results.json
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 5004.65it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.bias               | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# classifier.out_proj.bias   | MISSING    |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.weight | MISSING    |
# classifier.dense.bias      | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Epoch 1/10 | train_loss=0.5276 | dev_macro_f1=0.8035
# Writing model shards: 100% 1/1 [00:11<00:00, 11.07s/it]
# Epoch 2/10 | train_loss=0.3453 | dev_macro_f1=0.8253
# Writing model shards: 100% 1/1 [00:11<00:00, 11.60s/it]
# Epoch 3/10 | train_loss=0.2463 | dev_macro_f1=0.8216
# Epoch 4/10 | train_loss=0.1769 | dev_macro_f1=0.8320
# Writing model shards: 100% 1/1 [00:11<00:00, 11.72s/it]
# Epoch 5/10 | train_loss=0.1234 | dev_macro_f1=0.8230
# Epoch 6/10 | train_loss=0.0913 | dev_macro_f1=0.8233
# Epoch 7/10 | train_loss=0.0635 | dev_macro_f1=0.8311
# Early stopping at epoch 7 (best dev macro-F1=0.8320 @ epoch 4)
#
# Loading best checkpoint (dev macro-F1=0.8320) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 14837.56it/s]
# Test macro-F1: 0.8321
#
#               precision    recall  f1-score   support
#
#   not sexist      0.930     0.900     0.914      3030
#       sexist      0.715     0.788     0.750       970
#
#     accuracy                          0.873      4000
#    macro avg      0.823     0.844     0.832      4000
# weighted avg      0.878     0.873     0.875      4000
#
# Saved results to outputs/best_model_taskA_roberta-base_lr2e-5_bs32/results.json
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 8794.49it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.weight | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.dense.bias      | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Epoch 1/10 | train_loss=0.5158 | dev_macro_f1=0.7661
# Writing model shards: 100% 1/1 [00:41<00:00, 41.79s/it]
# Epoch 2/10 | train_loss=0.3738 | dev_macro_f1=0.8159
# Writing model shards: 100% 1/1 [00:38<00:00, 38.13s/it]
# Epoch 3/10 | train_loss=0.2760 | dev_macro_f1=0.8030
# Epoch 4/10 | train_loss=0.2100 | dev_macro_f1=0.8150
# Epoch 5/10 | train_loss=0.1412 | dev_macro_f1=0.8238
# Writing model shards: 100% 1/1 [00:21<00:00, 21.75s/it]
# Epoch 6/10 | train_loss=0.0880 | dev_macro_f1=0.8220
# Epoch 7/10 | train_loss=0.0581 | dev_macro_f1=0.8236
# Epoch 8/10 | train_loss=0.0364 | dev_macro_f1=0.8269
# Writing model shards: 100% 1/1 [00:06<00:00,  6.48s/it]
# Epoch 9/10 | train_loss=0.0185 | dev_macro_f1=0.8254
# Epoch 10/10 | train_loss=0.0167 | dev_macro_f1=0.8281
# Writing model shards: 100% 1/1 [00:06<00:00,  6.95s/it]
#
# Loading best checkpoint (dev macro-F1=0.8281) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 4440.90it/s]
# Test macro-F1: 0.8244
#
#               precision    recall  f1-score   support
#
#   not sexist      0.911     0.921     0.916      3030
#       sexist      0.746     0.720     0.732       970
#
#     accuracy                          0.873      4000
#    macro avg      0.828     0.821     0.824      4000
# weighted avg      0.871     0.873     0.872      4000
#
# Saved results to outputs/best_model_taskA_roberta-base_lr3e-5_bs16/results.json
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 4954.48it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.bias               | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.layer_norm.bias    | UNEXPECTED |
# classifier.out_proj.bias   | MISSING    |
# classifier.out_proj.weight | MISSING    |
# classifier.dense.weight    | MISSING    |
# classifier.dense.bias      | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Epoch 1/10 | train_loss=0.5152 | dev_macro_f1=0.7727
# Writing model shards: 100% 1/1 [00:46<00:00, 46.47s/it]
# Epoch 2/10 | train_loss=0.3502 | dev_macro_f1=0.8232
# Writing model shards: 100% 1/1 [00:12<00:00, 12.80s/it]
# Epoch 3/10 | train_loss=0.2428 | dev_macro_f1=0.8232
# Epoch 4/10 | train_loss=0.1557 | dev_macro_f1=0.8161
# Epoch 5/10 | train_loss=0.1060 | dev_macro_f1=0.8130
# Early stopping at epoch 5 (best dev macro-F1=0.8232 @ epoch 2)
#
# Loading best checkpoint (dev macro-F1=0.8232) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 5045.27it/s]
# Test macro-F1: 0.8150
#
#               precision    recall  f1-score   support
#
#   not sexist      0.918     0.895     0.907      3030
#       sexist      0.697     0.752     0.723       970
#
#     accuracy                          0.861      4000
#    macro avg      0.808     0.823     0.815      4000
# weighted avg      0.865     0.861     0.862      4000
#
# Saved results to outputs/best_model_taskA_roberta-base_lr3e-5_bs32/results.json
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 570/570 [00:00<00:00, 2.05MB/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 310kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 10.0MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 21.6MB/s]
# model.safetensors: 100% 440M/440M [00:06<00:00, 66.2MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 6051.90it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/interpretable-nlp-sexism-detection/src/train.py", line 242, in <module>
#     main()
#   File "/content/interpretable-nlp-sexism-detection/src/train.py", line 196, in main
#     total_loss += loss.item()
#                   ^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/interpretable-nlp-sexism-detection/src/train.py", line 40, in <module>
#     from sklearn.metrics import classification_report, f1_score
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#     ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/fixes.py", line 17, in <module>
#     import scipy.stats
#   File "/usr/local/lib/python3.12/dist-packages/scipy/stats/__init__.py", line 626, in <module>
#     from ._stats_py import *
#   File "/usr/local/lib/python3.12/dist-packages/scipy/stats/_stats_py.py", line 52, in <module>
#     from . import distributions
#   File "/usr/local/lib/python3.12/dist-packages/scipy/stats/distributions.py", line 10, in <module>
#     from . import _continuous_distns
#   File "/usr/local/lib/python3.12/dist-packages/scipy/stats/_continuous_distns.py", line 9340, in <module>
#   File "/usr/local/lib/python3.12/dist-packages/scipy/stats/_distn_infrastructure.py", line 1911, in __init__
#     self._construct_doc(docdict, dct.get(self.name))
#   File "/usr/local/lib/python3.12/dist-packages/scipy/stats/_distn_infrastructure.py", line 863, in _construct_doc
#     self.__doc__ = doccer.docformat(self.__doc__, tempdict)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/scipy/_lib/doccer.py", line 72, in docformat
#     icount = indentcount_lines(lines[1:])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/scipy/_lib/doccer.py", line 255, in indentcount_lines
#     stripped = line.lstrip()
#                ^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 6387.20it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/interpretable-nlp-sexism-detection/src/train.py", line 242, in <module>
#     main()
#   File "/content/interpretable-nlp-sexism-detection/src/train.py", line 196, in main
#     total_loss += loss.item()
#                   ^^^^^^^^^^^
# KeyboardInterrupt
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 7722.74it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/interpretable-nlp-sexism-detection/src/train.py", line 242, in <module>
#     main()
#   File "/content/interpretable-nlp-sexism-detection/src/train.py", line 196, in main
#     total_loss += loss.item()
#                   ^^^^^^^^^^^
# KeyboardInterrupt

# %%
import glob
import json

import pandas as pd

sweep_rows = []
for path in glob.glob("outputs/best_model_taskA_*_lr*_bs*/results.json"):
    with open(path) as f:
        r = json.load(f)
    sweep_rows.append({
        "model": r["model_name"],
        "run_name": r["run_name"],
        "lr": r["lr"],
        "batch_size": r["batch_size"],
        "dev_macro_f1": r["dev_macro_f1"],
    })

sweep_df = pd.DataFrame(sweep_rows).sort_values(["model", "dev_macro_f1"], ascending=[True, False])
print(sweep_df.to_string(index=False))

print("\nBest config per model (by dev macro-F1):")
best_per_model = sweep_df.sort_values("dev_macro_f1", ascending=False).groupby("model").first()
print(best_per_model[["lr", "batch_size", "dev_macro_f1"]])
print("\nUse these lr/batch_size values for --lr/--batch_size in the main Task A/B/C runs below, per model.")
# Out:
#        model    run_name      lr  batch_size  dev_macro_f1
# roberta-base lr2e-5_bs32 0.00002          32      0.831981
# roberta-base lr3e-5_bs16 0.00003          16      0.828141
# roberta-base lr2e-5_bs16 0.00002          16      0.825797
# roberta-base lr3e-5_bs32 0.00003          32      0.823215
#
# Best config per model (by dev macro-F1):
#                    lr  batch_size  dev_macro_f1
# model
# roberta-base  0.00002          32      0.831981
#
# Use these lr/batch_size values for --lr/--batch_size in the main Task A/B/C runs below, per model.

# %% [markdown]
# ## Task A — binary sexism classification (2-way)
#
# The best configuration learning rate 2e-5, batch size 32 which achieved a dev macro-F1 of 0.832 and was used for the final run.

# %%
# !python -m src.train --task A --model_name roberta-base --lr 2e-5 --batch_size 32
# Out:
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 4614.69it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# classifier.out_proj.weight | MISSING    |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.dense.bias      | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Epoch 1/10 | train_loss=0.5264 | dev_macro_f1=0.7998
# Writing model shards: 100% 1/1 [00:27<00:00, 27.27s/it]
# Epoch 2/10 | train_loss=0.3456 | dev_macro_f1=0.8218
# Writing model shards: 100% 1/1 [00:26<00:00, 26.78s/it]
# Epoch 3/10 | train_loss=0.2460 | dev_macro_f1=0.8209
# Epoch 4/10 | train_loss=0.1710 | dev_macro_f1=0.8324
# Writing model shards: 100% 1/1 [00:38<00:00, 38.59s/it]
# Epoch 5/10 | train_loss=0.1220 | dev_macro_f1=0.8261
# Epoch 6/10 | train_loss=0.0887 | dev_macro_f1=0.8261
# Epoch 7/10 | train_loss=0.0645 | dev_macro_f1=0.8226
# Early stopping at epoch 7 (best dev macro-F1=0.8324 @ epoch 4)
#
# Loading best checkpoint (dev macro-F1=0.8324) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 11123.86it/s]
# Test macro-F1: 0.8283
#
#               precision    recall  f1-score   support
#
#   not sexist      0.921     0.909     0.915      3030
#       sexist      0.726     0.758     0.742       970
#
#     accuracy                          0.872      4000
#    macro avg      0.824     0.833     0.828      4000
# weighted avg      0.874     0.872     0.873      4000
#
# Saved results to outputs/best_model_taskA_roberta-base/results.json

# %% [markdown]
# On the held-out test set, this configuration achieves a macro-F1 of 0.828, with precision/recall of 0.921/0.909 for not-sexist and 0.726/0.758 for sexist.

# %% [markdown]
# ## Persist checkpoints to Drive
#
# Colab runtimes are ephemeral — back up `outputs/` before the session disconnects,
# otherwise you lose every trained checkpoint.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p /content/drive/MyDrive/EDOS_DATA/outputs_backup
# !cp -r outputs/* /content/drive/MyDrive/EDOS_DATA/outputs_backup/
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###TASK A
#
# #BERT

# %%
from google.colab import drive
drive.mount('/content/drive')

MODELS = ["bert-base-uncased"]
LRS = ["2e-5", "3e-5"]
BATCH_SIZES = [16, 32]

DRIVE_BACKUP_DIR = "/content/drive/MyDrive/EDOS_DATA/outputs_backup"
# !mkdir -p {DRIVE_BACKUP_DIR}

for model in MODELS:
    for lr in LRS:
        for bs in BATCH_SIZES:
            run_name = f"lr{lr}_bs{bs}"
            # !python -m src.train --task A --model_name {model} --lr {lr} --batch_size {bs} --run_name {run_name}

            # Back up this config's checkpoint right away, before starting the next one
            run_dir = f"outputs/best_model_taskA_{model}_{run_name}"
            print(f"Backing up {run_dir} to Drive...")
            # !cp -r {run_dir} {DRIVE_BACKUP_DIR}/
            print(f"Done backing up {run_name}.\n")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 570/570 [00:00<00:00, 2.85MB/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 277kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 1.51MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 1.36MB/s]
# model.safetensors: 100% 440M/440M [00:05<00:00, 79.0MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 20289.43it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Epoch 1/10 | train_loss=0.5303 | dev_macro_f1=0.7824
# Writing model shards: 100% 1/1 [00:06<00:00,  6.11s/it]
# Epoch 2/10 | train_loss=0.3356 | dev_macro_f1=0.7930
# Writing model shards: 100% 1/1 [00:06<00:00,  6.05s/it]
# Epoch 3/10 | train_loss=0.2046 | dev_macro_f1=0.8123
# Writing model shards: 100% 1/1 [00:07<00:00,  7.08s/it]
# Epoch 4/10 | train_loss=0.1129 | dev_macro_f1=0.8148
# Writing model shards: 100% 1/1 [00:07<00:00,  7.29s/it]
# Epoch 5/10 | train_loss=0.0568 | dev_macro_f1=0.8196
# Writing model shards: 100% 1/1 [00:01<00:00,  1.71s/it]
# Epoch 6/10 | train_loss=0.0328 | dev_macro_f1=0.8097
# Epoch 7/10 | train_loss=0.0202 | dev_macro_f1=0.8205
# Writing model shards: 100% 1/1 [00:03<00:00,  3.50s/it]
# Epoch 8/10 | train_loss=0.0150 | dev_macro_f1=0.8271
# Writing model shards: 100% 1/1 [00:01<00:00,  1.41s/it]
# Epoch 9/10 | train_loss=0.0059 | dev_macro_f1=0.8270
# Epoch 10/10 | train_loss=0.0065 | dev_macro_f1=0.8225
#
# Loading best checkpoint (dev macro-F1=0.8271) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 5920.08it/s]
# Test macro-F1: 0.8195
#
#               precision    recall  f1-score   support
#
#   not sexist      0.907     0.923     0.915      3030
#       sexist      0.746     0.703     0.724       970
#
#     accuracy                          0.870      4000
#    macro avg      0.826     0.813     0.819      4000
# weighted avg      0.868     0.870     0.869      4000
#
# Saved results to outputs/best_model_taskA_bert-base-uncased_lr2e-5_bs16/results.json
# Backing up outputs/best_model_taskA_bert-base-uncased_lr2e-5_bs16 to Drive...
# Done backing up lr2e-5_bs16.
#
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 5455.30it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Epoch 1/10 | train_loss=0.5355 | dev_macro_f1=0.7641
# Writing model shards: 100% 1/1 [00:03<00:00,  3.49s/it]
# Epoch 2/10 | train_loss=0.3348 | dev_macro_f1=0.7826
# Writing model shards: 100% 1/1 [00:01<00:00,  1.37s/it]
# Epoch 3/10 | train_loss=0.1898 | dev_macro_f1=0.8125
# Writing model shards: 100% 1/1 [00:03<00:00,  3.12s/it]
# Epoch 4/10 | train_loss=0.1074 | dev_macro_f1=0.8104
# Epoch 5/10 | train_loss=0.0547 | dev_macro_f1=0.8243
# Writing model shards: 100% 1/1 [00:03<00:00,  3.25s/it]
# Epoch 6/10 | train_loss=0.0320 | dev_macro_f1=0.8127
# Epoch 7/10 | train_loss=0.0203 | dev_macro_f1=0.8150
# Epoch 8/10 | train_loss=0.0116 | dev_macro_f1=0.8199
# Early stopping at epoch 8 (best dev macro-F1=0.8243 @ epoch 5)
#
# Loading best checkpoint (dev macro-F1=0.8243) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 4729.83it/s]
# Test macro-F1: 0.8198
#
#               precision    recall  f1-score   support
#
#   not sexist      0.912     0.913     0.913      3030
#       sexist      0.728     0.726     0.727       970
#
#     accuracy                          0.868      4000
#    macro avg      0.820     0.819     0.820      4000
# weighted avg      0.868     0.868     0.868      4000
#
# Saved results to outputs/best_model_taskA_bert-base-uncased_lr2e-5_bs32/results.json
# Backing up outputs/best_model_taskA_bert-base-uncased_lr2e-5_bs32 to Drive...
# Done backing up lr2e-5_bs32.
#
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 6535.13it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Epoch 1/10 | train_loss=0.5122 | dev_macro_f1=0.7810
# Writing model shards: 100% 1/1 [00:01<00:00,  1.55s/it]
# Epoch 2/10 | train_loss=0.3235 | dev_macro_f1=0.7788
# Epoch 3/10 | train_loss=0.1838 | dev_macro_f1=0.8045
# Writing model shards: 100% 1/1 [00:06<00:00,  6.70s/it]
# Epoch 4/10 | train_loss=0.0951 | dev_macro_f1=0.8081
# Writing model shards: 100% 1/1 [00:07<00:00,  7.14s/it]
# Epoch 5/10 | train_loss=0.0457 | dev_macro_f1=0.8036
# Epoch 6/10 | train_loss=0.0236 | dev_macro_f1=0.8158
# Writing model shards: 100% 1/1 [00:01<00:00,  1.54s/it]
# Epoch 7/10 | train_loss=0.0170 | dev_macro_f1=0.8156
# Epoch 8/10 | train_loss=0.0063 | dev_macro_f1=0.8092
# Epoch 9/10 | train_loss=0.0044 | dev_macro_f1=0.8159
# Writing model shards: 100% 1/1 [00:08<00:00,  8.79s/it]
# Epoch 10/10 | train_loss=0.0037 | dev_macro_f1=0.8165
# Writing model shards: 100% 1/1 [00:08<00:00,  8.62s/it]
#
# Loading best checkpoint (dev macro-F1=0.8165) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 20538.78it/s]
# Test macro-F1: 0.8268
#
#               precision    recall  f1-score   support
#
#   not sexist      0.910     0.927     0.918      3030
#       sexist      0.757     0.714     0.735       970
#
#     accuracy                          0.875      4000
#    macro avg      0.834     0.821     0.827      4000
# weighted avg      0.873     0.875     0.874      4000
#
# Saved results to outputs/best_model_taskA_bert-base-uncased_lr3e-5_bs16/results.json
# Backing up outputs/best_model_taskA_bert-base-uncased_lr3e-5_bs16 to Drive...
# Done backing up lr3e-5_bs16.
#
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 6611.48it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Epoch 1/10 | train_loss=0.5161 | dev_macro_f1=0.7459
# Writing model shards: 100% 1/1 [00:06<00:00,  6.35s/it]
# Epoch 2/10 | train_loss=0.3191 | dev_macro_f1=0.8005
# Writing model shards: 100% 1/1 [00:06<00:00,  6.21s/it]
# Epoch 3/10 | train_loss=0.1634 | dev_macro_f1=0.8128
# Writing model shards: 100% 1/1 [00:01<00:00,  1.98s/it]
# Epoch 4/10 | train_loss=0.0855 | dev_macro_f1=0.8005
# Epoch 5/10 | train_loss=0.0504 | dev_macro_f1=0.8092
# Epoch 6/10 | train_loss=0.0227 | dev_macro_f1=0.8250
# Writing model shards: 100% 1/1 [00:06<00:00,  6.72s/it]
# Epoch 7/10 | train_loss=0.0156 | dev_macro_f1=0.8119
# Epoch 8/10 | train_loss=0.0095 | dev_macro_f1=0.8192
# Epoch 9/10 | train_loss=0.0075 | dev_macro_f1=0.8198
# Early stopping at epoch 9 (best dev macro-F1=0.8250 @ epoch 6)
#
# Loading best checkpoint (dev macro-F1=0.8250) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 4860.59it/s]
# Test macro-F1: 0.8175
#
#               precision    recall  f1-score   support
#
#   not sexist      0.914     0.908     0.911      3030
#       sexist      0.717     0.732     0.724       970
#
#     accuracy                          0.865      4000
#    macro avg      0.815     0.820     0.818      4000
# weighted avg      0.866     0.865     0.865      4000
#
# Saved results to outputs/best_model_taskA_bert-base-uncased_lr3e-5_bs32/results.json
# Backing up outputs/best_model_taskA_bert-base-uncased_lr3e-5_bs32 to Drive...
# Done backing up lr3e-5_bs32.

# %%
# !python -m src.train --task A --model_name bert-base-uncased --lr 2e-5 --batch_size 16
# Out:
# Device: cuda
# Task A: train=14000 dev=2000 test=4000 | labels=['not sexist', 'sexist']
# config.json: 100% 570/570 [00:00<00:00, 2.51MB/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 257kB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 100% 232k/232k [00:00<00:00, 14.7MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 4.11MB/s]
# model.safetensors: 100% 440M/440M [00:04<00:00, 97.3MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 8729.36it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [0.6602528095245361, 2.060035228729248]
# Epoch 1/10 | train_loss=0.5303 | dev_macro_f1=0.7824
# Writing model shards: 100% 1/1 [00:05<00:00,  5.13s/it]
# Epoch 2/10 | train_loss=0.3356 | dev_macro_f1=0.7930
# Writing model shards: 100% 1/1 [00:06<00:00,  6.17s/it]
# Epoch 3/10 | train_loss=0.2046 | dev_macro_f1=0.8123
# Writing model shards: 100% 1/1 [00:07<00:00,  7.42s/it]
# Epoch 4/10 | train_loss=0.1129 | dev_macro_f1=0.8148
# Writing model shards: 100% 1/1 [00:06<00:00,  7.00s/it]
# Epoch 5/10 | train_loss=0.0568 | dev_macro_f1=0.8196
# Writing model shards: 100% 1/1 [00:06<00:00,  6.62s/it]
# Epoch 6/10 | train_loss=0.0328 | dev_macro_f1=0.8097
# Epoch 7/10 | train_loss=0.0202 | dev_macro_f1=0.8205
# Writing model shards: 100% 1/1 [00:04<00:00,  4.87s/it]
# Epoch 8/10 | train_loss=0.0150 | dev_macro_f1=0.8271
# Writing model shards: 100% 1/1 [00:07<00:00,  7.13s/it]
# Epoch 9/10 | train_loss=0.0059 | dev_macro_f1=0.8270
# Epoch 10/10 | train_loss=0.0065 | dev_macro_f1=0.8225
#
# Loading best checkpoint (dev macro-F1=0.8271) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 5921.50it/s]
# Test macro-F1: 0.8195
#
#               precision    recall  f1-score   support
#
#   not sexist      0.907     0.923     0.915      3030
#       sexist      0.746     0.703     0.724       970
#
#     accuracy                          0.870      4000
#    macro avg      0.826     0.813     0.819      4000
# weighted avg      0.868     0.870     0.869      4000
#
# Saved results to outputs/best_model_taskA_bert-base-uncased/results.json

# %% [markdown]
# # TASK B

# %%
from google.colab import drive
drive.mount('/content/drive')

DRIVE_BACKUP_DIR = "/content/drive/MyDrive/EDOS_DATA/outputs_backup"
# !mkdir -p {DRIVE_BACKUP_DIR}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Roberta

# %%
LRS = ["2e-5", "3e-5"]
BATCH_SIZES = [16, 32]

for lr in LRS:
    for bs in BATCH_SIZES:
        run_name = f"lr{lr}_bs{bs}"
        # !python -m src.train --task B --model_name roberta-base --lr {lr} --batch_size {bs} --epochs 20 --run_name {run_name}

        run_dir = f"outputs/best_model_taskB_roberta-base_{run_name}"
        print(f"Backing up {run_dir} to Drive...")
        # !cp -r {run_dir} {DRIVE_BACKUP_DIR}/
        print(f"Done backing up {run_name}.\n")
# Out:
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 20282.23it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# classifier.out_proj.weight | MISSING    |
# classifier.dense.weight    | MISSING    |
# classifier.dense.bias      | MISSING    |
# classifier.out_proj.bias   | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [2.7403225898742676, 0.5342767238616943, 0.7291845679283142, 2.551051139831543]
# Epoch 1/20 | train_loss=1.3205 | dev_macro_f1=0.3311
# Writing model shards: 100% 1/1 [00:03<00:00,  3.60s/it]
# Epoch 2/20 | train_loss=0.9735 | dev_macro_f1=0.5770
# Writing model shards: 100% 1/1 [00:01<00:00,  1.60s/it]
# Epoch 3/20 | train_loss=0.6947 | dev_macro_f1=0.6287
# Writing model shards: 100% 1/1 [00:03<00:00,  3.43s/it]
# Epoch 4/20 | train_loss=0.4614 | dev_macro_f1=0.6051
# Epoch 5/20 | train_loss=0.3284 | dev_macro_f1=0.6352
# Writing model shards: 100% 1/1 [00:05<00:00,  5.90s/it]
# Epoch 6/20 | train_loss=0.2337 | dev_macro_f1=0.6286
# Epoch 7/20 | train_loss=0.1463 | dev_macro_f1=0.6130
# Epoch 8/20 | train_loss=0.0902 | dev_macro_f1=0.6154
# Early stopping at epoch 8 (best dev macro-F1=0.6352 @ epoch 5)
#
# Loading best checkpoint (dev macro-F1=0.6352) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 4810.15it/s]
# Test macro-F1: 0.6181
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.689     0.697     0.693        89
#                            2. derogation      0.675     0.654     0.664       454
#                             3. animosity      0.581     0.580     0.580       333
#                4. prejudiced discussions      0.500     0.574     0.535        94
#
#                                 accuracy                          0.625       970
#                                macro avg      0.611     0.626     0.618       970
#                             weighted avg      0.627     0.625     0.626       970
#
# Saved results to outputs/best_model_taskB_roberta-base_lr2e-5_bs16/results.json
# Backing up outputs/best_model_taskB_roberta-base_lr2e-5_bs16 to Drive...
# Done backing up lr2e-5_bs16.
#
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 18122.12it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.weight | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.dense.bias      | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [2.7403225898742676, 0.5342767238616943, 0.7291845679283142, 2.551051139831543]
# Epoch 1/20 | train_loss=1.3678 | dev_macro_f1=0.2670
# Writing model shards: 100% 1/1 [00:02<00:00,  2.05s/it]
# Epoch 2/20 | train_loss=1.0684 | dev_macro_f1=0.5305
# Writing model shards: 100% 1/1 [00:17<00:00, 17.86s/it]
# Epoch 3/20 | train_loss=0.7844 | dev_macro_f1=0.5694
# Writing model shards: 100% 1/1 [00:18<00:00, 18.14s/it]
# Epoch 4/20 | train_loss=0.5832 | dev_macro_f1=0.5378
# Epoch 5/20 | train_loss=0.4523 | dev_macro_f1=0.5830
# Writing model shards: 100% 1/1 [00:42<00:00, 42.87s/it]
# Epoch 6/20 | train_loss=0.3372 | dev_macro_f1=0.6341
# Writing model shards: 100% 1/1 [00:43<00:00, 43.37s/it]
# Epoch 7/20 | train_loss=0.2395 | dev_macro_f1=0.6318
# Epoch 8/20 | train_loss=0.1715 | dev_macro_f1=0.6372
# Writing model shards: 100% 1/1 [00:12<00:00, 12.56s/it]
# Epoch 9/20 | train_loss=0.1145 | dev_macro_f1=0.6385
# Writing model shards: 100% 1/1 [00:12<00:00, 12.75s/it]
# Epoch 10/20 | train_loss=0.0838 | dev_macro_f1=0.6404
# Writing model shards: 100% 1/1 [00:06<00:00,  6.78s/it]
# Epoch 11/20 | train_loss=0.0661 | dev_macro_f1=0.6241
# Epoch 12/20 | train_loss=0.0450 | dev_macro_f1=0.6465
# Writing model shards: 100% 1/1 [00:38<00:00, 38.24s/it]
# Epoch 13/20 | train_loss=0.0313 | dev_macro_f1=0.6179
# Epoch 14/20 | train_loss=0.0257 | dev_macro_f1=0.6286
# Epoch 15/20 | train_loss=0.0176 | dev_macro_f1=0.6203
# Early stopping at epoch 15 (best dev macro-F1=0.6465 @ epoch 12)
#
# Loading best checkpoint (dev macro-F1=0.6465) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 4646.26it/s]
# Test macro-F1: 0.6027
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.640     0.640     0.640        89
#                            2. derogation      0.642     0.648     0.645       454
#                             3. animosity      0.577     0.565     0.571       333
#                4. prejudiced discussions      0.546     0.564     0.555        94
#
#                                 accuracy                          0.610       970
#                                macro avg      0.601     0.604     0.603       970
#                             weighted avg      0.610     0.610     0.610       970
#
# Saved results to outputs/best_model_taskB_roberta-base_lr2e-5_bs32/results.json
# Backing up outputs/best_model_taskB_roberta-base_lr2e-5_bs32 to Drive...
# Done backing up lr2e-5_bs32.
#
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 6708.22it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.bias               | UNEXPECTED |
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.dense.bias      | MISSING    |
# classifier.out_proj.weight | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [2.7403225898742676, 0.5342767238616943, 0.7291845679283142, 2.551051139831543]
# Epoch 1/20 | train_loss=1.3016 | dev_macro_f1=0.4098
# Writing model shards: 100% 1/1 [00:16<00:00, 16.65s/it]
# Epoch 2/20 | train_loss=0.9791 | dev_macro_f1=0.6076
# Writing model shards: 100% 1/1 [00:48<00:00, 48.28s/it]
# Epoch 3/20 | train_loss=0.7008 | dev_macro_f1=0.6567
# Writing model shards: 100% 1/1 [00:06<00:00,  6.91s/it]
# Epoch 4/20 | train_loss=0.4698 | dev_macro_f1=0.6077
# Epoch 5/20 | train_loss=0.3325 | dev_macro_f1=0.6298
# Epoch 6/20 | train_loss=0.2142 | dev_macro_f1=0.6202
# Early stopping at epoch 6 (best dev macro-F1=0.6567 @ epoch 3)
#
# Loading best checkpoint (dev macro-F1=0.6567) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 4353.18it/s]
# Test macro-F1: 0.5856
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.688     0.596     0.639        89
#                            2. derogation      0.638     0.621     0.629       454
#                             3. animosity      0.555     0.580     0.567       333
#                4. prejudiced discussions      0.485     0.532     0.508        94
#
#                                 accuracy                          0.596       970
#                                macro avg      0.592     0.582     0.586       970
#                             weighted avg      0.599     0.596     0.597       970
#
# Saved results to outputs/best_model_taskB_roberta-base_lr3e-5_bs16/results.json
# Backing up outputs/best_model_taskB_roberta-base_lr3e-5_bs16 to Drive...
# Done backing up lr3e-5_bs16.
#
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 6701.14it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# classifier.out_proj.weight | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.dense.weight    | MISSING    |
# classifier.dense.bias      | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [2.7403225898742676, 0.5342767238616943, 0.7291845679283142, 2.551051139831543]
# Epoch 1/20 | train_loss=1.3327 | dev_macro_f1=0.3775
# Writing model shards: 100% 1/1 [00:07<00:00,  7.84s/it]
# Epoch 2/20 | train_loss=0.9946 | dev_macro_f1=0.5917
# Writing model shards: 100% 1/1 [00:30<00:00, 30.25s/it]
# Epoch 3/20 | train_loss=0.7054 | dev_macro_f1=0.6213
# Writing model shards: 100% 1/1 [00:45<00:00, 45.20s/it]
# Epoch 4/20 | train_loss=0.4970 | dev_macro_f1=0.5232
# Epoch 5/20 | train_loss=0.3718 | dev_macro_f1=0.6182
# Epoch 6/20 | train_loss=0.2616 | dev_macro_f1=0.6453
# Writing model shards: 100% 1/1 [00:01<00:00,  1.90s/it]
# Epoch 7/20 | train_loss=0.1741 | dev_macro_f1=0.6477
# Writing model shards: 100% 1/1 [00:01<00:00,  1.86s/it]
# Epoch 8/20 | train_loss=0.1175 | dev_macro_f1=0.6196
# Epoch 9/20 | train_loss=0.0687 | dev_macro_f1=0.6137
# Epoch 10/20 | train_loss=0.0501 | dev_macro_f1=0.6131
# Early stopping at epoch 10 (best dev macro-F1=0.6477 @ epoch 7)
#
# Loading best checkpoint (dev macro-F1=0.6477) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 11197.29it/s]
# Test macro-F1: 0.6081
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.656     0.685     0.670        89
#                            2. derogation      0.693     0.557     0.618       454
#                             3. animosity      0.569     0.634     0.599       333
#                4. prejudiced discussions      0.454     0.681     0.545        94
#
#                                 accuracy                          0.607       970
#                                macro avg      0.593     0.639     0.608       970
#                             weighted avg      0.624     0.607     0.609       970
#
# Saved results to outputs/best_model_taskB_roberta-base_lr3e-5_bs32/results.json
# Backing up outputs/best_model_taskB_roberta-base_lr3e-5_bs32 to Drive...
# Done backing up lr3e-5_bs32.

# %% [markdown]
# BERT

# %%
LRS = ["2e-5", "3e-5"]
BATCH_SIZES = [16, 32]

for lr in LRS:
    for bs in BATCH_SIZES:
        run_name = f"lr{lr}_bs{bs}"
        # !python -m src.train --task B --model_name bert-base-uncased --lr {lr} --batch_size {bs} --epochs 20 --run_name {run_name}

        run_dir = f"outputs/best_model_taskB_bert-base-uncased_{run_name}"
        print(f"Backing up {run_dir} to Drive...")
        # !cp -r {run_dir} {DRIVE_BACKUP_DIR}/
        print(f"Done backing up {run_name}.\n")
# Out:
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 705.70it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [2.7403225898742676, 0.5342767238616943, 0.7291845679283142, 2.551051139831543]
# Epoch 1/20 | train_loss=1.3411 | dev_macro_f1=0.3615
# Writing model shards: 100% 1/1 [00:01<00:00,  1.22s/it]
# Epoch 2/20 | train_loss=1.0211 | dev_macro_f1=0.5390
# Writing model shards: 100% 1/1 [00:01<00:00,  1.46s/it]
# Epoch 3/20 | train_loss=0.6530 | dev_macro_f1=0.5595
# Writing model shards: 100% 1/1 [00:01<00:00,  1.35s/it]
# Epoch 4/20 | train_loss=0.4101 | dev_macro_f1=0.6279
# Writing model shards: 100% 1/1 [00:04<00:00,  4.24s/it]
# Epoch 5/20 | train_loss=0.2373 | dev_macro_f1=0.6064
# Epoch 6/20 | train_loss=0.1183 | dev_macro_f1=0.6045
# Epoch 7/20 | train_loss=0.0571 | dev_macro_f1=0.5923
# Early stopping at epoch 7 (best dev macro-F1=0.6279 @ epoch 4)
#
# Loading best checkpoint (dev macro-F1=0.6279) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 19543.67it/s]
# Test macro-F1: 0.5754
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.640     0.640     0.640        89
#                            2. derogation      0.604     0.762     0.674       454
#                             3. animosity      0.635     0.474     0.543       333
#                4. prejudiced discussions      0.576     0.362     0.444        94
#
#                                 accuracy                          0.613       970
#                                macro avg      0.614     0.560     0.575       970
#                             weighted avg      0.615     0.613     0.604       970
#
# Saved results to outputs/best_model_taskB_bert-base-uncased_lr2e-5_bs16/results.json
# Backing up outputs/best_model_taskB_bert-base-uncased_lr2e-5_bs16 to Drive...
# Done backing up lr2e-5_bs16.
#
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 5890.09it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [2.7403225898742676, 0.5342767238616943, 0.7291845679283142, 2.551051139831543]
# Epoch 1/20 | train_loss=1.3671 | dev_macro_f1=0.2601
# Writing model shards: 100% 1/1 [00:01<00:00,  1.28s/it]
# Epoch 2/20 | train_loss=1.0756 | dev_macro_f1=0.4676
# Writing model shards: 100% 1/1 [00:06<00:00,  6.97s/it]
# Epoch 3/20 | train_loss=0.7408 | dev_macro_f1=0.5918
# Writing model shards: 100% 1/1 [00:01<00:00,  1.36s/it]
# Epoch 4/20 | train_loss=0.4938 | dev_macro_f1=0.6014
# Writing model shards: 100% 1/1 [00:01<00:00,  1.51s/it]
# Epoch 5/20 | train_loss=0.3609 | dev_macro_f1=0.6183
# Writing model shards: 100% 1/1 [00:01<00:00,  1.36s/it]
# Epoch 6/20 | train_loss=0.2381 | dev_macro_f1=0.6184
# Writing model shards: 100% 1/1 [00:01<00:00,  1.40s/it]
# Epoch 7/20 | train_loss=0.1336 | dev_macro_f1=0.6253
# Writing model shards: 100% 1/1 [00:03<00:00,  3.22s/it]
# Epoch 8/20 | train_loss=0.0708 | dev_macro_f1=0.6450
# Writing model shards: 100% 1/1 [00:03<00:00,  3.04s/it]
# Epoch 9/20 | train_loss=0.0444 | dev_macro_f1=0.5929
# Epoch 10/20 | train_loss=0.0252 | dev_macro_f1=0.6107
# Epoch 11/20 | train_loss=0.0153 | dev_macro_f1=0.5973
# Early stopping at epoch 11 (best dev macro-F1=0.6450 @ epoch 8)
#
# Loading best checkpoint (dev macro-F1=0.6450) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 4807.90it/s]
# Test macro-F1: 0.5914
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.645     0.674     0.659        89
#                            2. derogation      0.609     0.749     0.672       454
#                             3. animosity      0.626     0.441     0.518       333
#                4. prejudiced discussions      0.548     0.489     0.517        94
#
#                                 accuracy                          0.611       970
#                                macro avg      0.607     0.588     0.591       970
#                             weighted avg      0.612     0.611     0.603       970
#
# Saved results to outputs/best_model_taskB_bert-base-uncased_lr2e-5_bs32/results.json
# Backing up outputs/best_model_taskB_bert-base-uncased_lr2e-5_bs32 to Drive...
# Done backing up lr2e-5_bs32.
#
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 5628.38it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [2.7403225898742676, 0.5342767238616943, 0.7291845679283142, 2.551051139831543]
# Epoch 1/20 | train_loss=1.3137 | dev_macro_f1=0.4593
# Writing model shards: 100% 1/1 [00:04<00:00,  4.69s/it]
# Epoch 2/20 | train_loss=0.9714 | dev_macro_f1=0.5813
# Writing model shards: 100% 1/1 [00:11<00:00, 11.68s/it]
# Epoch 3/20 | train_loss=0.6053 | dev_macro_f1=0.6001
# Writing model shards: 100% 1/1 [00:02<00:00,  2.31s/it]
# Epoch 4/20 | train_loss=0.3452 | dev_macro_f1=0.5833
# Epoch 5/20 | train_loss=0.1515 | dev_macro_f1=0.6108
# Writing model shards: 100% 1/1 [00:41<00:00, 41.91s/it]
# Epoch 6/20 | train_loss=0.0717 | dev_macro_f1=0.5908
# Epoch 7/20 | train_loss=0.0358 | dev_macro_f1=0.6390
# Writing model shards: 100% 1/1 [00:01<00:00,  1.60s/it]
# Epoch 8/20 | train_loss=0.0195 | dev_macro_f1=0.6166
# Epoch 9/20 | train_loss=0.0108 | dev_macro_f1=0.6270
# Epoch 10/20 | train_loss=0.0048 | dev_macro_f1=0.6309
# Early stopping at epoch 10 (best dev macro-F1=0.6390 @ epoch 7)
#
# Loading best checkpoint (dev macro-F1=0.6390) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 16461.10it/s]
# Test macro-F1: 0.5758
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.644     0.629     0.636        89
#                            2. derogation      0.605     0.698     0.648       454
#                             3. animosity      0.579     0.483     0.527       333
#                4. prejudiced discussions      0.531     0.457     0.491        94
#
#                                 accuracy                          0.595       970
#                                macro avg      0.590     0.567     0.576       970
#                             weighted avg      0.592     0.595     0.590       970
#
# Saved results to outputs/best_model_taskB_bert-base-uncased_lr3e-5_bs16/results.json
# Backing up outputs/best_model_taskB_bert-base-uncased_lr3e-5_bs16 to Drive...
# Done backing up lr3e-5_bs16.
#
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Loading weights: 100% 199/199 [00:00<00:00, 6264.38it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [2.7403225898742676, 0.5342767238616943, 0.7291845679283142, 2.551051139831543]
# Epoch 1/20 | train_loss=1.3390 | dev_macro_f1=0.3392
# Writing model shards: 100% 1/1 [00:06<00:00,  6.57s/it]
# Epoch 2/20 | train_loss=0.9990 | dev_macro_f1=0.4825
# Writing model shards: 100% 1/1 [00:09<00:00,  9.77s/it]
# Epoch 3/20 | train_loss=0.6503 | dev_macro_f1=0.5926
# Writing model shards: 100% 1/1 [00:01<00:00,  1.65s/it]
# Epoch 4/20 | train_loss=0.4372 | dev_macro_f1=0.5836
# Epoch 5/20 | train_loss=0.2774 | dev_macro_f1=0.6061
# Writing model shards: 100% 1/1 [00:21<00:00, 21.90s/it]
# Epoch 6/20 | train_loss=0.1413 | dev_macro_f1=0.6075
# Writing model shards: 100% 1/1 [00:43<00:00, 43.21s/it]
# Epoch 7/20 | train_loss=0.0645 | dev_macro_f1=0.6084
# Writing model shards: 100% 1/1 [00:01<00:00,  1.59s/it]
# Epoch 8/20 | train_loss=0.0351 | dev_macro_f1=0.6000
# Epoch 9/20 | train_loss=0.0206 | dev_macro_f1=0.5976
# Epoch 10/20 | train_loss=0.0130 | dev_macro_f1=0.6117
# Writing model shards: 100% 1/1 [00:09<00:00,  9.24s/it]
# Epoch 11/20 | train_loss=0.0104 | dev_macro_f1=0.6223
# Writing model shards: 100% 1/1 [00:33<00:00, 33.61s/it]
# Epoch 12/20 | train_loss=0.0092 | dev_macro_f1=0.6084
# Epoch 13/20 | train_loss=0.0050 | dev_macro_f1=0.6112
# Epoch 14/20 | train_loss=0.0043 | dev_macro_f1=0.6151
# Early stopping at epoch 14 (best dev macro-F1=0.6223 @ epoch 11)
#
# Loading best checkpoint (dev macro-F1=0.6223) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 5673.47it/s]
# Test macro-F1: 0.5682
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.659     0.607     0.632        89
#                            2. derogation      0.596     0.786     0.678       454
#                             3. animosity      0.613     0.414     0.495       333
#                4. prejudiced discussions      0.578     0.394     0.468        94
#
#                                 accuracy                          0.604       970
#                                macro avg      0.611     0.550     0.568       970
#                             weighted avg      0.606     0.604     0.591       970
#
# Saved results to outputs/best_model_taskB_bert-base-uncased_lr3e-5_bs32/results.json
# Backing up outputs/best_model_taskB_bert-base-uncased_lr3e-5_bs32 to Drive...
# Done backing up lr3e-5_bs32.

# %%
import glob
import json
import pandas as pd

sweep_rows = []
for path in glob.glob("outputs/best_model_taskB_*_lr*_bs*/results.json"):
    with open(path) as f:
        r = json.load(f)
    sweep_rows.append({
        "model": r["model_name"],
        "run_name": r["run_name"],
        "lr": r["lr"],
        "batch_size": r["batch_size"],
        "dev_macro_f1": r["dev_macro_f1"],
    })

sweep_df = pd.DataFrame(sweep_rows).sort_values(["model", "dev_macro_f1"], ascending=[True, False])
print(sweep_df.to_string(index=False))

print("\nBest config per model (by dev macro-F1):")
best_per_model_B = sweep_df.sort_values("dev_macro_f1", ascending=False).groupby("model").first()
print(best_per_model_B[["lr", "batch_size", "dev_macro_f1"]])
# Out:
#             model    run_name      lr  batch_size  dev_macro_f1
# bert-base-uncased lr2e-5_bs32 0.00002          32      0.645029
# bert-base-uncased lr3e-5_bs16 0.00003          16      0.639047
# bert-base-uncased lr2e-5_bs16 0.00002          16      0.627943
# bert-base-uncased lr3e-5_bs32 0.00003          32      0.622328
#      roberta-base lr3e-5_bs16 0.00003          16      0.656671
#      roberta-base lr3e-5_bs32 0.00003          32      0.647676
#      roberta-base lr2e-5_bs32 0.00002          32      0.646475
#      roberta-base lr2e-5_bs16 0.00002          16      0.635243
#
# Best config per model (by dev macro-F1):
#                         lr  batch_size  dev_macro_f1
# model
# bert-base-uncased  0.00002          32      0.645029
# roberta-base       0.00003          16      0.656671

# %%
# !python -m src.train --task B --model_name roberta-base --lr 3e-5 --batch_size 16 --epochs 20
# !python -m src.train --task B --model_name bert-base-uncased --lr 2e-5 --batch_size 32 --epochs 20

# !cp -r outputs/best_model_taskB_roberta-base {DRIVE_BACKUP_DIR}/
# !cp -r outputs/best_model_taskB_bert-base-uncased {DRIVE_BACKUP_DIR}/
# Out:
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 5388.18it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.dense.bias      | MISSING    |
# classifier.out_proj.weight | MISSING    |
# classifier.out_proj.bias   | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [2.7403225898742676, 0.5342767238616943, 0.7291845679283142, 2.551051139831543]
# Epoch 1/20 | train_loss=1.3016 | dev_macro_f1=0.4098
# Writing model shards: 100% 1/1 [00:06<00:00,  6.35s/it]
# Epoch 2/20 | train_loss=0.9791 | dev_macro_f1=0.6076
# Writing model shards: 100% 1/1 [00:50<00:00, 50.22s/it]
# Epoch 3/20 | train_loss=0.7008 | dev_macro_f1=0.6567
# Writing model shards: 100% 1/1 [00:03<00:00,  3.24s/it]
# Epoch 4/20 | train_loss=0.4698 | dev_macro_f1=0.6077
# Epoch 5/20 | train_loss=0.3325 | dev_macro_f1=0.6298
# Epoch 6/20 | train_loss=0.2142 | dev_macro_f1=0.6202
# Early stopping at epoch 6 (best dev macro-F1=0.6567 @ epoch 3)
#
# Loading best checkpoint (dev macro-F1=0.6567) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 21753.45it/s]
# Test macro-F1: 0.5856
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.688     0.596     0.639        89
#                            2. derogation      0.638     0.621     0.629       454
#                             3. animosity      0.555     0.580     0.567       333
#                4. prejudiced discussions      0.485     0.532     0.508        94
#
#                                 accuracy                          0.596       970
#                                macro avg      0.592     0.582     0.586       970
#                             weighted avg      0.599     0.596     0.597       970
#
# Saved results to outputs/best_model_taskB_roberta-base/results.json
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 4950.28it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [2.7403225898742676, 0.5342767238616943, 0.7291845679283142, 2.551051139831543]
# Epoch 1/20 | train_loss=1.3671 | dev_macro_f1=0.2622
# Writing model shards: 100% 1/1 [00:03<00:00,  3.22s/it]
# Epoch 2/20 | train_loss=1.0779 | dev_macro_f1=0.4931
# Writing model shards: 100% 1/1 [00:05<00:00,  5.36s/it]
# Epoch 3/20 | train_loss=0.7456 | dev_macro_f1=0.5649
# Writing model shards: 100% 1/1 [00:01<00:00,  1.60s/it]
# Epoch 4/20 | train_loss=0.5014 | dev_macro_f1=0.5943
# Writing model shards: 100% 1/1 [00:07<00:00,  7.40s/it]
# Epoch 5/20 | train_loss=0.3707 | dev_macro_f1=0.6166
# Writing model shards: 100% 1/1 [00:01<00:00,  1.31s/it]
# Epoch 6/20 | train_loss=0.2512 | dev_macro_f1=0.6327
# Writing model shards: 100% 1/1 [00:04<00:00,  4.64s/it]
# Epoch 7/20 | train_loss=0.1467 | dev_macro_f1=0.6423
# Writing model shards: 100% 1/1 [00:01<00:00,  1.57s/it]
# Epoch 8/20 | train_loss=0.0825 | dev_macro_f1=0.6453
# Writing model shards: 100% 1/1 [00:01<00:00,  1.44s/it]
# Epoch 9/20 | train_loss=0.0516 | dev_macro_f1=0.5752
# Epoch 10/20 | train_loss=0.0207 | dev_macro_f1=0.6411
# Epoch 11/20 | train_loss=0.0155 | dev_macro_f1=0.6169
# Early stopping at epoch 11 (best dev macro-F1=0.6453 @ epoch 8)
#
# Loading best checkpoint (dev macro-F1=0.6453) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 6030.91it/s]
# Test macro-F1: 0.5791
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.587     0.719     0.646        89
#                            2. derogation      0.641     0.621     0.631       454
#                             3. animosity      0.555     0.577     0.566       333
#                4. prejudiced discussions      0.533     0.426     0.473        94
#
#                                 accuracy                          0.596       970
#                                macro avg      0.579     0.586     0.579       970
#                             weighted avg      0.596     0.596     0.595       970
#
# Saved results to outputs/best_model_taskB_bert-base-uncased/results.json

# %% [markdown]
# Augemnted dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
DRIVE_BACKUP_DIR = "/content/drive/MyDrive/EDOS_DATA/outputs_backup"
# !mkdir -p {DRIVE_BACKUP_DIR}
# Out:
# Mounted at /content/drive

# %%
# !grep -n "pivot_lang" src/train.py
# Out:
# 102:        "--pivot_lang",
# 141:            train_df, target_classes, pivot_lang=args.pivot_lang, device=str(device)
# 226:        "pivot_lang": args.pivot_lang if args.augment == "backtranslate" else None,

# %%
# !python -m src.train --task B --model_name roberta-base --lr 3e-5 --batch_size 16 --epochs 20 --augment backtranslate --augment_classes 0,3 --pivot_lang fr --run_name augmented
# !python -m src.train --task B --model_name bert-base-uncased --lr 2e-5 --batch_size 32 --epochs 20 --augment backtranslate --augment_classes 0,3 --pivot_lang fr --run_name augmented

# !cp -r outputs/best_model_taskB_roberta-base_augmented {DRIVE_BACKUP_DIR}/
# !cp -r outputs/best_model_taskB_bert-base-uncased_augmented {DRIVE_BACKUP_DIR}/
# Out:
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Augmenting classes [0, 3] with back-translation (train split only)
# tokenizer_config.json: 100% 42.0/42.0 [00:00<00:00, 272kB/s]
# source.spm: 100% 778k/778k [00:00<00:00, 76.8MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# target.spm: 100% 802k/802k [00:00<00:00, 247MB/s]
# vocab.json: 100% 1.34M/1.34M [00:00<00:00, 131MB/s]
# config.json: 100% 1.42k/1.42k [00:00<00:00, 4.56MB/s]
#
# pytorch_model.bin: downloading bytes:   0% 0.00/301M [00:00<?, ?B/s]
# pytorch_model.bin: downloading bytes:  11% 32.8M/301M [00:01<00:16, 16.5MB/s]
# pytorch_model.bin: downloading bytes:  24% 72.3M/301M [00:02<00:05, 42.0MB/s, 3.14MB/s  ]
# pytorch_model.bin: downloading bytes:  66% 199M/301M [00:02<00:00, 156MB/s, 14.8MB/s  ]
# pytorch_model.bin: downloading bytes:  82% 246M/301M [00:02<00:00, 177MB/s, 20.7MB/s  ]
# pytorch_model.bin: downloading bytes: 100% 281M/281M [00:02<00:00, 98.0MB/s, 25.5MB/s  ]
# pytorch_model.bin: reconstructing file: 100% 301M/301M [00:02<00:00, 105MB/s, 27.7MB/s  ]
# Loading weights: 100% 258/258 [00:00<00:00, 36655.05it/s]
#
# model.safetensors: downloading bytes:   0% 0.00/301M [00:00<?, ?B/s]
#
# generation_config.json: 100% 293/293 [00:00<00:00, 1.88MB/s]
#
#
# tokenizer_config.json: 100% 42.0/42.0 [00:00<00:00, 283kB/s]
# model.safetensors: downloading bytes:   0% 1.49M/301M [00:01<04:57, 1.01MB/s]
#
# source.spm: 100% 802k/802k [00:00<00:00, 60.0MB/s]
# model.safetensors: downloading bytes:  45% 134M/301M [00:01<00:01, 135MB/s, 8.58MB/s  ]
#
# target.spm: 100% 778k/778k [00:00<00:00, 66.8MB/s]
# model.safetensors: downloading bytes:  58% 175M/301M [00:01<00:00, 179MB/s, 12.8MB/s  ]
# model.safetensors: downloading bytes:  73% 219M/301M [00:01<00:00, 228MB/s, 16.5MB/s  ]
# model.safetensors: reconstructing file:  23% 68.0M/301M [00:02<00:05, 45.0MB/s,  123kB/s  ]
#
# vocab.json: 100% 1.34M/1.34M [00:00<00:00, 20.0MB/s]
#
# model.safetensors: downloading bytes: 100% 280M/280M [00:02<00:00, 113MB/s, 25.4MB/s  ]
# model.safetensors: reconstructing file: 100% 301M/301M [00:02<00:00, 122MB/s, 28.1MB/s  ]
# config.json: 100% 1.42k/1.42k [00:00<00:00, 4.42MB/s]
#
# model.safetensors: downloading bytes:  44% 134M/301M [00:02<00:02, 76.4MB/s, 11.4MB/s  ]
# model.safetensors: downloading bytes:  65% 196M/301M [00:06<00:02, 35.3MB/s, 12.9MB/s  ]
# model.safetensors: reconstructing file:  59% 178M/301M [00:06<00:04, 27.4MB/s, 8.65MB/s  ]
# model.safetensors: downloading bytes:  89% 267M/301M [00:06<00:00, 84.5MB/s, 16.7MB/s  ]
# model.safetensors: downloading bytes: 100% 280M/280M [00:08<00:00, 32.3MB/s, 17.6MB/s  ]
# model.safetensors: reconstructing file: 100% 301M/301M [00:08<00:00, 34.7MB/s, 21.1MB/s  ]
# Loading weights: 100% 256/256 [00:00<00:00, 9518.31it/s]
# generation_config.json: 100% 293/293 [00:00<00:00, 1.06MB/s]
# Train size after augmentation: 4041
# config.json: 100% 481/481 [00:00<00:00, 2.53MB/s]
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 137kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 8.64MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 10.6MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 8.23MB/s]
#
# model.safetensors: downloading bytes:  51% 256M/499M [00:02<00:01, 184MB/s, 21.9MB/s  ]
# model.safetensors: downloading bytes:  62% 312M/499M [00:02<00:01, 141MB/s, 26.7MB/s  ]
# model.safetensors: reconstructing file:  67% 335M/499M [00:03<00:01, 126MB/s, 12.6MB/s  ]
# model.safetensors: downloading bytes:  67% 332M/499M [00:03<00:01, 113MB/s, 28.3MB/s  ]
# model.safetensors: downloading bytes: 100% 335M/335M [00:03<00:00, 93.8MB/s, 28.5MB/s  ]
# model.safetensors: reconstructing file: 100% 499M/499M [00:03<00:00, 140MB/s, 44.3MB/s  ]
# Loading weights: 100% 197/197 [00:00<00:00, 5157.79it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.bias               | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.layer_norm.bias    | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.out_proj.weight | MISSING    |
# classifier.dense.bias      | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [1.6294355392456055, 0.6353773474693298, 0.8671673536300659, 1.5168918371200562]
# Epoch 1/20 | train_loss=1.2258 | dev_macro_f1=0.4782
# Writing model shards: 100% 1/1 [00:03<00:00,  3.21s/it]
# Epoch 2/20 | train_loss=0.8279 | dev_macro_f1=0.5599
# Writing model shards: 100% 1/1 [00:06<00:00,  6.04s/it]
# Epoch 3/20 | train_loss=0.5162 | dev_macro_f1=0.5954
# Writing model shards: 100% 1/1 [00:07<00:00,  7.36s/it]
# Epoch 4/20 | train_loss=0.3415 | dev_macro_f1=0.5860
# Epoch 5/20 | train_loss=0.2130 | dev_macro_f1=0.5320
# Epoch 6/20 | train_loss=0.1454 | dev_macro_f1=0.5934
# Early stopping at epoch 6 (best dev macro-F1=0.5954 @ epoch 3)
#
# Loading best checkpoint (dev macro-F1=0.5954) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 8233.04it/s]
# Test macro-F1: 0.5992
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.589     0.742     0.657        89
#                            2. derogation      0.697     0.542     0.610       454
#                             3. animosity      0.534     0.688     0.601       333
#                4. prejudiced discussions      0.592     0.479     0.529        94
#
#                                 accuracy                          0.604       970
#                                macro avg      0.603     0.612     0.599       970
#                             weighted avg      0.621     0.604     0.603       970
#
# Saved results to outputs/best_model_taskB_roberta-base_augmented/results.json
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Augmenting classes [0, 3] with back-translation (train split only)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 258/258 [00:00<00:00, 35540.28it/s]
# Loading weights: 100% 256/256 [00:00<00:00, 5273.44it/s]
# Train size after augmentation: 4041
# config.json: 100% 570/570 [00:00<00:00, 2.52MB/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 191kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 3.32MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 1.06MB/s]
#
# model.safetensors: downloading bytes:  51% 223M/440M [00:01<00:00, 223MB/s, 17.6MB/s  ]
# model.safetensors: downloading bytes:  67% 295M/440M [00:02<00:00, 269MB/s, 24.3MB/s  ]
# model.safetensors: downloading bytes:  87% 383M/440M [00:02<00:00, 283MB/s, 31.7MB/s  ]
# model.safetensors: reconstructing file:  46% 201M/440M [00:02<00:02, 95.4MB/s, 12.6MB/s  ]
# model.safetensors: downloading bytes: 100% 415M/415M [00:05<00:00, 72.8MB/s, 37.6MB/s  ]
# model.safetensors: reconstructing file: 100% 440M/440M [00:05<00:00, 77.2MB/s, 35.0MB/s  ]
# Loading weights: 100% 199/199 [00:00<00:00, 6795.96it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [1.6294355392456055, 0.6353773474693298, 0.8671673536300659, 1.5168918371200562]
# Epoch 1/20 | train_loss=1.3188 | dev_macro_f1=0.4282
# Writing model shards: 100% 1/1 [00:06<00:00,  6.96s/it]
# Epoch 2/20 | train_loss=0.9298 | dev_macro_f1=0.5679
# Writing model shards: 100% 1/1 [00:01<00:00,  1.44s/it]
# Epoch 3/20 | train_loss=0.5967 | dev_macro_f1=0.5918
# Writing model shards: 100% 1/1 [00:01<00:00,  1.48s/it]
# Epoch 4/20 | train_loss=0.3994 | dev_macro_f1=0.6080
# Writing model shards: 100% 1/1 [00:03<00:00,  3.20s/it]
# Epoch 5/20 | train_loss=0.2627 | dev_macro_f1=0.5979
# Epoch 6/20 | train_loss=0.1502 | dev_macro_f1=0.6064
# Epoch 7/20 | train_loss=0.0800 | dev_macro_f1=0.5726
# Early stopping at epoch 7 (best dev macro-F1=0.6080 @ epoch 4)
#
# Loading best checkpoint (dev macro-F1=0.6080) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 5141.71it/s]
# Test macro-F1: 0.5599
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.566     0.629     0.596        89
#                            2. derogation      0.634     0.630     0.632       454
#                             3. animosity      0.613     0.465     0.529       333
#                4. prejudiced discussions      0.377     0.670     0.483        94
#
#                                 accuracy                          0.577       970
#                                macro avg      0.547     0.599     0.560       970
#                             weighted avg      0.596     0.577     0.579       970
#
# Saved results to outputs/best_model_taskB_bert-base-uncased_augmented/results.json

# %%
# !python -m src.train --task B --model_name roberta-base --lr 3e-5 --batch_size 16 --epochs 20 --augment backtranslate --augment_classes 0,3 --run_name augmented_nl
# !python -m src.train --task B --model_name bert-base-uncased --lr 2e-5 --batch_size 32 --epochs 20 --augment backtranslate --augment_classes 0,3 --run_name augmented_nl

# !cp -r outputs/best_model_taskB_roberta-base_augmented_nl {DRIVE_BACKUP_DIR}/
# !cp -r outputs/best_model_taskB_bert-base-uncased_augmented_nl {DRIVE_BACKUP_DIR}/
# Out:
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Augmenting classes [0, 3] with back-translation (train split only)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json: 100% 42.0/42.0 [00:00<00:00, 130kB/s]
# source.spm: 100% 790k/790k [00:00<00:00, 73.6MB/s]
# target.spm: 100% 814k/814k [00:00<00:00, 135MB/s]
# vocab.json: 100% 1.66M/1.66M [00:00<00:00, 127MB/s]
# config.json: 100% 1.38k/1.38k [00:00<00:00, 5.92MB/s]
#
# pytorch_model.bin: downloading bytes:   6% 17.9M/316M [00:02<00:25, 11.7MB/s, 17.2kB/s  ]
# pytorch_model.bin: downloading bytes:  12% 39.0M/316M [00:02<00:10, 26.5MB/s, 2.64MB/s  ]
# pytorch_model.bin: downloading bytes:  21% 65.7M/316M [00:02<00:04, 50.5MB/s, 4.62MB/s  ]
# pytorch_model.bin: downloading bytes:  62% 196M/316M [00:02<00:00, 232MB/s, 13.9MB/s  ]
# pytorch_model.bin: reconstructing file:  21% 67.3M/316M [00:04<00:15, 16.3MB/s, 3.75MB/s  ]
# pytorch_model.bin: downloading bytes:  72% 228M/316M [00:04<00:01, 54.5MB/s, 18.0MB/s  ]
# pytorch_model.bin: downloading bytes:  91% 288M/316M [00:06<00:00, 33.5MB/s, 20.0MB/s  ]
# pytorch_model.bin: reconstructing file:  90% 285M/316M [00:06<00:00, 46.4MB/s, 19.4MB/s  ]
# pytorch_model.bin: reconstructing file:  95% 302M/316M [00:07<00:00, 42.4MB/s, 20.3MB/s  ]
# pytorch_model.bin: downloading bytes: 100% 293M/293M [00:09<00:00, 30.0MB/s, 15.7MB/s  ]
# pytorch_model.bin: reconstructing file: 100% 316M/316M [00:09<00:00, 32.4MB/s, 18.8MB/s  ]
# Loading weights: 100% 258/258 [00:00<00:00, 28995.22it/s]
#
# model.safetensors: downloading bytes:   0% 0.00/316M [00:00<?, ?B/s]
#
# generation_config.json: 100% 293/293 [00:00<00:00, 1.85MB/s]
#
#
# tokenizer_config.json: 100% 42.0/42.0 [00:00<00:00, 191kB/s]
#
#
# source.spm: 100% 814k/814k [00:00<00:00, 118MB/s]
#
#
# target.spm: 100% 790k/790k [00:00<00:00, 330MB/s]
# model.safetensors: downloading bytes:   2% 5.43M/316M [00:01<01:53, 2.73MB/s]
#
# vocab.json: 100% 1.66M/1.66M [00:00<00:00, 80.6MB/s]
# model.safetensors: downloading bytes:  19% 58.7M/316M [00:02<00:06, 42.0MB/s, 3.00MB/s  ]
# model.safetensors: downloading bytes:  51% 160M/316M [00:03<00:01, 97.6MB/s, 11.3MB/s  ]
#
# config.json: 100% 1.38k/1.38k [00:00<00:00, 5.56MB/s]
# model.safetensors: downloading bytes:  65% 206M/316M [00:04<00:01, 73.2MB/s, 17.0MB/s  ]
# model.safetensors: reconstructing file:  22% 71.0M/316M [00:04<00:15, 15.5MB/s, 3.97MB/s  ]
# pytorch_model.bin: downloading bytes:  14% 45.8M/316M [00:02<00:08, 32.3MB/s, 2.73MB/s  ]
# pytorch_model.bin: downloading bytes:  19% 60.1M/316M [00:03<00:14, 17.2MB/s, 5.03MB/s  ]
# model.safetensors: reconstructing file:  46% 145M/316M [00:08<00:09, 17.3MB/s, 5.87MB/s  ]
# pytorch_model.bin: downloading bytes:  47% 150M/316M [00:04<00:01, 85.6MB/s, 9.97MB/s  ]
# pytorch_model.bin: reconstructing file:   7% 22.2M/316M [00:04<01:12, 4.03MB/s, 1.61MB/s  ]
# pytorch_model.bin: downloading bytes:  67% 213M/316M [00:05<00:00, 129MB/s, 14.2MB/s  ]
# pytorch_model.bin: downloading bytes:  75% 237M/316M [00:05<00:00, 148MB/s, 17.4MB/s  ]
# pytorch_model.bin: downloading bytes:  89% 283M/316M [00:05<00:00, 147MB/s, 22.8MB/s  ]
# pytorch_model.bin: reconstructing file:  27% 83.8M/316M [00:06<00:07, 30.5MB/s, 3.11MB/s  ]
# model.safetensors: downloading bytes: 100% 292M/292M [00:11<00:00, 25.6MB/s, 16.6MB/s  ]
# model.safetensors: reconstructing file: 100% 316M/316M [00:11<00:00, 27.7MB/s, 21.5MB/s  ]
#
# pytorch_model.bin: reconstructing file:  55% 172M/316M [00:07<00:02, 49.2MB/s, 6.87MB/s  ]
# pytorch_model.bin: downloading bytes: 100% 291M/291M [00:07<00:00, 36.6MB/s, 19.5MB/s  ]
# pytorch_model.bin: reconstructing file: 100% 316M/316M [00:07<00:00, 39.8MB/s, 25.1MB/s  ]
# Loading weights: 100% 258/258 [00:00<00:00, 37584.41it/s]
#
# model.safetensors: downloading bytes:   0% 0.00/316M [00:00<?, ?B/s]
#
# generation_config.json: 100% 293/293 [00:00<00:00, 1.55MB/s]
# model.safetensors: downloading bytes:  90% 285M/316M [00:05<00:00, 54.9MB/s, 21.8MB/s  ]
# model.safetensors: reconstructing file:  66% 209M/316M [00:06<00:03, 33.0MB/s]
# model.safetensors: reconstructing file:  72% 227M/316M [00:06<00:02, 36.2MB/s, 18.1MB/s  ]
# model.safetensors: reconstructing file:  80% 252M/316M [00:06<00:01, 42.7MB/s, 19.5MB/s  ]
# model.safetensors: downloading bytes: 100% 291M/291M [00:06<00:00, 43.1MB/s, 21.5MB/s  ]
# model.safetensors: reconstructing file: 100% 316M/316M [00:06<00:00, 46.9MB/s, 26.7MB/s  ]
# Train size after augmentation: 4041
# Loading weights: 100% 197/197 [00:00<00:00, 625.28it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.dense.bias      | MISSING    |
# classifier.out_proj.weight | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [1.6294355392456055, 0.6353773474693298, 0.8671673536300659, 1.5168918371200562]
# Epoch 1/20 | train_loss=1.2285 | dev_macro_f1=0.4230
# Writing model shards: 100% 1/1 [00:01<00:00,  1.55s/it]
# Epoch 2/20 | train_loss=0.8110 | dev_macro_f1=0.5713
# Writing model shards: 100% 1/1 [00:01<00:00,  1.96s/it]
# Epoch 3/20 | train_loss=0.5255 | dev_macro_f1=0.5485
# Epoch 4/20 | train_loss=0.3581 | dev_macro_f1=0.6011
# Writing model shards: 100% 1/1 [00:06<00:00,  6.88s/it]
# Epoch 5/20 | train_loss=0.2449 | dev_macro_f1=0.6153
# Writing model shards: 100% 1/1 [00:01<00:00,  1.76s/it]
# Epoch 6/20 | train_loss=0.1547 | dev_macro_f1=0.6241
# Writing model shards: 100% 1/1 [00:01<00:00,  1.67s/it]
# Epoch 7/20 | train_loss=0.0988 | dev_macro_f1=0.5945
# Epoch 8/20 | train_loss=0.0741 | dev_macro_f1=0.6065
# Epoch 9/20 | train_loss=0.0605 | dev_macro_f1=0.6083
# Early stopping at epoch 9 (best dev macro-F1=0.6241 @ epoch 6)
#
# Loading best checkpoint (dev macro-F1=0.6241) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 5098.18it/s]
# Test macro-F1: 0.5972
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.655     0.640     0.648        89
#                            2. derogation      0.633     0.709     0.669       454
#                             3. animosity      0.579     0.517     0.546       333
#                4. prejudiced discussions      0.584     0.479     0.526        94
#
#                                 accuracy                          0.614       970
#                                macro avg      0.613     0.586     0.597       970
#                             weighted avg      0.612     0.614     0.611       970
#
# Saved results to outputs/best_model_taskB_roberta-base_augmented_nl/results.json
# Device: cuda
# Task B: train=3398 dev=486 test=970 | labels=['1. threats, plans to harm and incitement', '2. derogation', '3. animosity', '4. prejudiced discussions']
# Augmenting classes [0, 3] with back-translation (train split only)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 258/258 [00:00<00:00, 34862.45it/s]
# Loading weights: 100% 258/258 [00:00<00:00, 33779.63it/s]
# Train size after augmentation: 4041
# Loading weights: 100% 199/199 [00:00<00:00, 829.39it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [1.6294355392456055, 0.6353773474693298, 0.8671673536300659, 1.5168918371200562]
# Epoch 1/20 | train_loss=1.3406 | dev_macro_f1=0.3667
# Writing model shards: 100% 1/1 [00:05<00:00,  5.92s/it]
# Epoch 2/20 | train_loss=0.9582 | dev_macro_f1=0.4511
# Writing model shards: 100% 1/1 [00:01<00:00,  1.53s/it]
# Epoch 3/20 | train_loss=0.6297 | dev_macro_f1=0.5835
# Writing model shards: 100% 1/1 [00:09<00:00,  9.79s/it]
# Epoch 4/20 | train_loss=0.4082 | dev_macro_f1=0.5941
# Writing model shards: 100% 1/1 [00:01<00:00,  1.68s/it]
# Epoch 5/20 | train_loss=0.2912 | dev_macro_f1=0.5859
# Epoch 6/20 | train_loss=0.1770 | dev_macro_f1=0.5983
# Writing model shards: 100% 1/1 [00:01<00:00,  1.58s/it]
# Epoch 7/20 | train_loss=0.0904 | dev_macro_f1=0.5826
# Epoch 8/20 | train_loss=0.0457 | dev_macro_f1=0.6118
# Writing model shards: 100% 1/1 [00:03<00:00,  3.42s/it]
# Epoch 9/20 | train_loss=0.0219 | dev_macro_f1=0.5968
# Epoch 10/20 | train_loss=0.0184 | dev_macro_f1=0.6199
# Writing model shards: 100% 1/1 [00:10<00:00, 10.49s/it]
# Epoch 11/20 | train_loss=0.0062 | dev_macro_f1=0.6242
# Writing model shards: 100% 1/1 [00:11<00:00, 11.00s/it]
# Epoch 12/20 | train_loss=0.0075 | dev_macro_f1=0.6290
# Writing model shards: 100% 1/1 [00:10<00:00, 10.62s/it]
# Epoch 13/20 | train_loss=0.0048 | dev_macro_f1=0.6227
# Epoch 14/20 | train_loss=0.0029 | dev_macro_f1=0.6118
# Epoch 15/20 | train_loss=0.0019 | dev_macro_f1=0.6096
# Early stopping at epoch 15 (best dev macro-F1=0.6290 @ epoch 12)
#
# Loading best checkpoint (dev macro-F1=0.6290) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 4856.92it/s]
# Test macro-F1: 0.5954
#
#                                           precision    recall  f1-score   support
#
# 1. threats, plans to harm and incitement      0.667     0.652     0.659        89
#                            2. derogation      0.639     0.656     0.648       454
#                             3. animosity      0.581     0.592     0.586       333
#                4. prejudiced discussions      0.538     0.447     0.488        94
#
#                                 accuracy                          0.613       970
#                                macro avg      0.606     0.587     0.595       970
#                             weighted avg      0.612     0.613     0.612       970
#
# Saved results to outputs/best_model_taskB_bert-base-uncased_augmented_nl/results.json

# %% [markdown]
# # TASK C

# %%
from google.colab import drive
drive.mount('/content/drive')

MODELS = ["roberta-base", "bert-base-uncased"]
LRS = ["2e-5", "3e-5"]
BATCH_SIZES = [16, 32]

DRIVE_BACKUP_DIR = "/content/drive/MyDrive/EDOS_DATA/outputs_backup"
# !mkdir -p {DRIVE_BACKUP_DIR}

for model in MODELS:
    for lr in LRS:
        for bs in BATCH_SIZES:
            run_name = f"lr{lr}_bs{bs}"
            # !python -m src.train --task C --model_name {model} --lr {lr} --batch_size {bs} --epochs 20 --patience 3 --run_name {run_name}

            # Back up this config's checkpoint right away, before starting the next one
            run_dir = f"outputs/best_model_taskC_{model}_{run_name}"
            print(f"Backing up {run_dir} to Drive...")
            # !cp -r {run_dir} {DRIVE_BACKUP_DIR}/
            print(f"Done backing up {run_name}.\n")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Device: cuda
# Task C: train=3398 dev=486 test=970 | labels=['1.1 threats of harm', '1.2 incitement and encouragement of harm', '2.1 descriptive attacks', '2.2 aggressive and emotive attacks', '2.3 dehumanising attacks & overt sexual objectification', '3.1 casual use of gendered slurs, profanities, and insults', '3.2 immutable gender differences and gender stereotypes', '3.3 backhanded gendered compliments', '3.4 condescending explanations or unwelcome advice', '4.1 supporting mistreatment of individual women', '4.2 supporting systemic discrimination against women as a group']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 1597.70it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.dense.bias      | MISSING    |
# classifier.out_proj.weight | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [5.516233921051025, 1.2161775827407837, 0.4308355450630188, 0.45900312066078186, 1.5445454120635986, 0.4849436283111572, 0.7407891750335693, 4.826704502105713, 6.572534084320068, 4.11878776550293, 1.1973220109939575]
# Epoch 1/20 | train_loss=2.3768 | dev_macro_f1=0.1348
# Writing model shards: 100% 1/1 [00:10<00:00, 10.43s/it]
# Epoch 2/20 | train_loss=1.9238 | dev_macro_f1=0.3359
# Writing model shards: 100% 1/1 [00:03<00:00,  3.95s/it]
# Epoch 3/20 | train_loss=1.4571 | dev_macro_f1=0.3574
# Writing model shards: 100% 1/1 [00:11<00:00, 11.97s/it]
# Epoch 4/20 | train_loss=1.0820 | dev_macro_f1=0.4454
# Writing model shards: 100% 1/1 [00:21<00:00, 21.27s/it]
# Epoch 5/20 | train_loss=0.7642 | dev_macro_f1=0.4083
# Epoch 6/20 | train_loss=0.5588 | dev_macro_f1=0.4145
# Epoch 7/20 | train_loss=0.3673 | dev_macro_f1=0.4131
# Early stopping at epoch 7 (best dev macro-F1=0.4454 @ epoch 4)
#
# Loading best checkpoint (dev macro-F1=0.4454) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 8318.09it/s]
# Test macro-F1: 0.4341
#
#                                                                  precision    recall  f1-score   support
#
#                                             1.1 threats of harm      0.474     0.562     0.514        16
#                        1.2 incitement and encouragement of harm      0.591     0.534     0.561        73
#                                         2.1 descriptive attacks      0.524     0.473     0.497       205
#                              2.2 aggressive and emotive attacks      0.540     0.422     0.474       192
#         2.3 dehumanising attacks & overt sexual objectification      0.359     0.649     0.463        57
#      3.1 casual use of gendered slurs, profanities, and insults      0.580     0.599     0.589       182
#         3.2 immutable gender differences and gender stereotypes      0.513     0.504     0.508       119
#                             3.3 backhanded gendered compliments      0.500     0.111     0.182        18
#              3.4 condescending explanations or unwelcome advice      0.333     0.071     0.118        14
#                 4.1 supporting mistreatment of individual women      0.400     0.381     0.390        21
# 4.2 supporting systemic discrimination against women as a group      0.391     0.616     0.479        73
#
#                                                        accuracy                          0.503       970
#                                                       macro avg      0.473     0.448     0.434       970
#                                                    weighted avg      0.515     0.503     0.499       970
#
# Saved results to outputs/best_model_taskC_roberta-base_lr2e-5_bs16/results.json
# Backing up outputs/best_model_taskC_roberta-base_lr2e-5_bs16 to Drive...
# Done backing up lr2e-5_bs16.
#
# Device: cuda
# Task C: train=3398 dev=486 test=970 | labels=['1.1 threats of harm', '1.2 incitement and encouragement of harm', '2.1 descriptive attacks', '2.2 aggressive and emotive attacks', '2.3 dehumanising attacks & overt sexual objectification', '3.1 casual use of gendered slurs, profanities, and insults', '3.2 immutable gender differences and gender stereotypes', '3.3 backhanded gendered compliments', '3.4 condescending explanations or unwelcome advice', '4.1 supporting mistreatment of individual women', '4.2 supporting systemic discrimination against women as a group']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 5629.32it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.out_proj.weight | MISSING    |
# classifier.dense.bias      | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [5.516233921051025, 1.2161775827407837, 0.4308355450630188, 0.45900312066078186, 1.5445454120635986, 0.4849436283111572, 0.7407891750335693, 4.826704502105713, 6.572534084320068, 4.11878776550293, 1.1973220109939575]
# Epoch 1/20 | train_loss=2.4012 | dev_macro_f1=0.0641
# Writing model shards: 100% 1/1 [00:01<00:00,  1.87s/it]
# Epoch 2/20 | train_loss=2.1484 | dev_macro_f1=0.2594
# Writing model shards: 100% 1/1 [00:22<00:00, 22.41s/it]
# Epoch 3/20 | train_loss=1.6214 | dev_macro_f1=0.3499
# Writing model shards: 100% 1/1 [00:37<00:00, 37.78s/it]
# Epoch 4/20 | train_loss=1.2452 | dev_macro_f1=0.3746
# Writing model shards: 100% 1/1 [00:22<00:00, 22.93s/it]
# Epoch 5/20 | train_loss=0.9102 | dev_macro_f1=0.3824
# Writing model shards: 100% 1/1 [00:43<00:00, 43.74s/it]
# Epoch 6/20 | train_loss=0.6573 | dev_macro_f1=0.4217
# Writing model shards: 100% 1/1 [00:13<00:00, 13.73s/it]
# Epoch 7/20 | train_loss=0.5076 | dev_macro_f1=0.4240
# Writing model shards: 100% 1/1 [00:42<00:00, 42.78s/it]
# Epoch 8/20 | train_loss=0.3852 | dev_macro_f1=0.4362
# Writing model shards: 100% 1/1 [00:13<00:00, 13.09s/it]
# Epoch 9/20 | train_loss=0.3035 | dev_macro_f1=0.4296
# Epoch 10/20 | train_loss=0.2464 | dev_macro_f1=0.4179
# Epoch 11/20 | train_loss=0.1891 | dev_macro_f1=0.4237
# Early stopping at epoch 11 (best dev macro-F1=0.4362 @ epoch 8)
#
# Loading best checkpoint (dev macro-F1=0.4362) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 5431.71it/s]
# Test macro-F1: 0.4434
#
#                                                                  precision    recall  f1-score   support
#
#                                             1.1 threats of harm      0.500     0.562     0.529        16
#                        1.2 incitement and encouragement of harm      0.551     0.671     0.605        73
#                                         2.1 descriptive attacks      0.495     0.439     0.465       205
#                              2.2 aggressive and emotive attacks      0.500     0.625     0.556       192
#         2.3 dehumanising attacks & overt sexual objectification      0.462     0.316     0.375        57
#      3.1 casual use of gendered slurs, profanities, and insults      0.660     0.588     0.622       182
#         3.2 immutable gender differences and gender stereotypes      0.427     0.538     0.476       119
#                             3.3 backhanded gendered compliments      0.400     0.222     0.286        18
#              3.4 condescending explanations or unwelcome advice      0.000     0.000     0.000        14
#                 4.1 supporting mistreatment of individual women      0.562     0.429     0.486        21
# 4.2 supporting systemic discrimination against women as a group      0.544     0.425     0.477        73
#
#                                                        accuracy                          0.516       970
#                                                       macro avg      0.464     0.438     0.443       970
#                                                    weighted avg      0.517     0.516     0.511       970
#
# Saved results to outputs/best_model_taskC_roberta-base_lr2e-5_bs32/results.json
# Backing up outputs/best_model_taskC_roberta-base_lr2e-5_bs32 to Drive...
# Done backing up lr2e-5_bs32.
#
# Device: cuda
# Task C: train=3398 dev=486 test=970 | labels=['1.1 threats of harm', '1.2 incitement and encouragement of harm', '2.1 descriptive attacks', '2.2 aggressive and emotive attacks', '2.3 dehumanising attacks & overt sexual objectification', '3.1 casual use of gendered slurs, profanities, and insults', '3.2 immutable gender differences and gender stereotypes', '3.3 backhanded gendered compliments', '3.4 condescending explanations or unwelcome advice', '4.1 supporting mistreatment of individual women', '4.2 supporting systemic discrimination against women as a group']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 7641.24it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# classifier.out_proj.bias   | MISSING    |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.weight | MISSING    |
# classifier.dense.bias      | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [5.516233921051025, 1.2161775827407837, 0.4308355450630188, 0.45900312066078186, 1.5445454120635986, 0.4849436283111572, 0.7407891750335693, 4.826704502105713, 6.572534084320068, 4.11878776550293, 1.1973220109939575]
# Epoch 1/20 | train_loss=2.3680 | dev_macro_f1=0.1454
# Writing model shards: 100% 1/1 [00:08<00:00,  8.09s/it]
# Epoch 2/20 | train_loss=1.9323 | dev_macro_f1=0.2717
# Writing model shards: 100% 1/1 [00:47<00:00, 47.79s/it]
# Epoch 3/20 | train_loss=1.4527 | dev_macro_f1=0.3812
# Writing model shards: 100% 1/1 [00:48<00:00, 48.76s/it]
# Epoch 4/20 | train_loss=1.0569 | dev_macro_f1=0.4130
# Writing model shards: 100% 1/1 [00:12<00:00, 12.25s/it]
# Epoch 5/20 | train_loss=0.6987 | dev_macro_f1=0.3938
# Epoch 6/20 | train_loss=0.4986 | dev_macro_f1=0.4482
# Writing model shards: 100% 1/1 [00:11<00:00, 11.95s/it]
# Epoch 7/20 | train_loss=0.3359 | dev_macro_f1=0.4269
# Epoch 8/20 | train_loss=0.2497 | dev_macro_f1=0.4152
# Epoch 9/20 | train_loss=0.1783 | dev_macro_f1=0.4290
# Early stopping at epoch 9 (best dev macro-F1=0.4482 @ epoch 6)
#
# Loading best checkpoint (dev macro-F1=0.4482) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 4968.44it/s]
# Test macro-F1: 0.4644
#
#                                                                  precision    recall  f1-score   support
#
#                                             1.1 threats of harm      0.615     0.500     0.552        16
#                        1.2 incitement and encouragement of harm      0.625     0.616     0.621        73
#                                         2.1 descriptive attacks      0.540     0.459     0.496       205
#                              2.2 aggressive and emotive attacks      0.470     0.656     0.548       192
#         2.3 dehumanising attacks & overt sexual objectification      0.448     0.526     0.484        57
#      3.1 casual use of gendered slurs, profanities, and insults      0.728     0.500     0.593       182
#         3.2 immutable gender differences and gender stereotypes      0.481     0.420     0.448       119
#                             3.3 backhanded gendered compliments      0.500     0.167     0.250        18
#              3.4 condescending explanations or unwelcome advice      0.074     0.143     0.098        14
#                 4.1 supporting mistreatment of individual women      0.462     0.571     0.511        21
# 4.2 supporting systemic discrimination against women as a group      0.466     0.562     0.509        73
#
#                                                        accuracy                          0.518       970
#                                                       macro avg      0.492     0.465     0.464       970
#                                                    weighted avg      0.542     0.518     0.519       970
#
# Saved results to outputs/best_model_taskC_roberta-base_lr3e-5_bs16/results.json
# Backing up outputs/best_model_taskC_roberta-base_lr3e-5_bs16 to Drive...
# Done backing up lr3e-5_bs16.
#
# Device: cuda
# Task C: train=3398 dev=486 test=970 | labels=['1.1 threats of harm', '1.2 incitement and encouragement of harm', '2.1 descriptive attacks', '2.2 aggressive and emotive attacks', '2.3 dehumanising attacks & overt sexual objectification', '3.1 casual use of gendered slurs, profanities, and insults', '3.2 immutable gender differences and gender stereotypes', '3.3 backhanded gendered compliments', '3.4 condescending explanations or unwelcome advice', '4.1 supporting mistreatment of individual women', '4.2 supporting systemic discrimination against women as a group']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 5409.38it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# classifier.dense.bias      | MISSING    |
# classifier.dense.weight    | MISSING    |
# classifier.out_proj.bias   | MISSING    |
# classifier.out_proj.weight | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [5.516233921051025, 1.2161775827407837, 0.4308355450630188, 0.45900312066078186, 1.5445454120635986, 0.4849436283111572, 0.7407891750335693, 4.826704502105713, 6.572534084320068, 4.11878776550293, 1.1973220109939575]
# Epoch 1/20 | train_loss=2.3954 | dev_macro_f1=0.1217
# Writing model shards: 100% 1/1 [00:32<00:00, 32.51s/it]
# Epoch 2/20 | train_loss=2.0168 | dev_macro_f1=0.2666
# Writing model shards: 100% 1/1 [00:26<00:00, 26.66s/it]
# Epoch 3/20 | train_loss=1.5144 | dev_macro_f1=0.3737
# Writing model shards: 100% 1/1 [00:52<00:00, 52.86s/it]
# Epoch 4/20 | train_loss=1.0905 | dev_macro_f1=0.4098
# Writing model shards: 100% 1/1 [00:38<00:00, 38.10s/it]
# Epoch 5/20 | train_loss=0.7172 | dev_macro_f1=0.3886
# Epoch 6/20 | train_loss=0.5285 | dev_macro_f1=0.4442
# Writing model shards: 100% 1/1 [00:44<00:00, 44.21s/it]
# Epoch 7/20 | train_loss=0.3715 | dev_macro_f1=0.3924
# Epoch 8/20 | train_loss=0.2603 | dev_macro_f1=0.4152
# Epoch 9/20 | train_loss=0.1893 | dev_macro_f1=0.4024
# Early stopping at epoch 9 (best dev macro-F1=0.4442 @ epoch 6)
#
# Loading best checkpoint (dev macro-F1=0.4442) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 5130.38it/s]
# Test macro-F1: 0.4322
#
#                                                                  precision    recall  f1-score   support
#
#                                             1.1 threats of harm      0.346     0.562     0.429        16
#                        1.2 incitement and encouragement of harm      0.511     0.658     0.575        73
#                                         2.1 descriptive attacks      0.493     0.493     0.493       205
#                              2.2 aggressive and emotive attacks      0.520     0.542     0.531       192
#         2.3 dehumanising attacks & overt sexual objectification      0.308     0.491     0.378        57
#      3.1 casual use of gendered slurs, profanities, and insults      0.701     0.489     0.576       182
#         3.2 immutable gender differences and gender stereotypes      0.500     0.454     0.476       119
#                             3.3 backhanded gendered compliments      0.500     0.278     0.357        18
#              3.4 condescending explanations or unwelcome advice      0.143     0.071     0.095        14
#                 4.1 supporting mistreatment of individual women      0.316     0.571     0.407        21
# 4.2 supporting systemic discrimination against women as a group      0.469     0.411     0.438        73
#
#                                                        accuracy                          0.496       970
#                                                       macro avg      0.437     0.456     0.432       970
#                                                    weighted avg      0.516     0.496     0.498       970
#
# Saved results to outputs/best_model_taskC_roberta-base_lr3e-5_bs32/results.json
# Backing up outputs/best_model_taskC_roberta-base_lr3e-5_bs32 to Drive...
# Done backing up lr3e-5_bs32.
#
# Device: cuda
# Task C: train=3398 dev=486 test=970 | labels=['1.1 threats of harm', '1.2 incitement and encouragement of harm', '2.1 descriptive attacks', '2.2 aggressive and emotive attacks', '2.3 dehumanising attacks & overt sexual objectification', '3.1 casual use of gendered slurs, profanities, and insults', '3.2 immutable gender differences and gender stereotypes', '3.3 backhanded gendered compliments', '3.4 condescending explanations or unwelcome advice', '4.1 supporting mistreatment of individual women', '4.2 supporting systemic discrimination against women as a group']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 883.82it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [5.516233921051025, 1.2161775827407837, 0.4308355450630188, 0.45900312066078186, 1.5445454120635986, 0.4849436283111572, 0.7407891750335693, 4.826704502105713, 6.572534084320068, 4.11878776550293, 1.1973220109939575]
# Epoch 1/20 | train_loss=2.4144 | dev_macro_f1=0.1082
# Writing model shards: 100% 1/1 [00:55<00:00, 55.60s/it]
# Epoch 2/20 | train_loss=2.0683 | dev_macro_f1=0.3333
# Writing model shards: 100% 1/1 [00:17<00:00, 17.16s/it]
# Epoch 3/20 | train_loss=1.4722 | dev_macro_f1=0.4280
# Writing model shards: 100% 1/1 [00:08<00:00,  8.67s/it]
# Epoch 4/20 | train_loss=0.9601 | dev_macro_f1=0.4419
# Writing model shards: 100% 1/1 [00:36<00:00, 36.34s/it]
# Epoch 5/20 | train_loss=0.5690 | dev_macro_f1=0.4669
# Writing model shards: 100% 1/1 [00:08<00:00,  8.99s/it]
# Epoch 6/20 | train_loss=0.3194 | dev_macro_f1=0.4732
# Writing model shards: 100% 1/1 [00:32<00:00, 32.79s/it]
# Epoch 7/20 | train_loss=0.1741 | dev_macro_f1=0.4468
# Epoch 8/20 | train_loss=0.0880 | dev_macro_f1=0.4219
# Epoch 9/20 | train_loss=0.0476 | dev_macro_f1=0.4027
# Early stopping at epoch 9 (best dev macro-F1=0.4732 @ epoch 6)
#
# Loading best checkpoint (dev macro-F1=0.4732) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 5414.33it/s]
# Test macro-F1: 0.4385
#
#                                                                  precision    recall  f1-score   support
#
#                                             1.1 threats of harm      0.545     0.375     0.444        16
#                        1.2 incitement and encouragement of harm      0.568     0.740     0.643        73
#                                         2.1 descriptive attacks      0.560     0.546     0.553       205
#                              2.2 aggressive and emotive attacks      0.515     0.620     0.563       192
#         2.3 dehumanising attacks & overt sexual objectification      0.467     0.491     0.479        57
#      3.1 casual use of gendered slurs, profanities, and insults      0.692     0.544     0.609       182
#         3.2 immutable gender differences and gender stereotypes      0.537     0.546     0.542       119
#                             3.3 backhanded gendered compliments      0.231     0.167     0.194        18
#              3.4 condescending explanations or unwelcome advice      0.000     0.000     0.000        14
#                 4.1 supporting mistreatment of individual women      0.333     0.238     0.278        21
# 4.2 supporting systemic discrimination against women as a group      0.506     0.534     0.520        73
#
#                                                        accuracy                          0.546       970
#                                                       macro avg      0.451     0.436     0.439       970
#                                                    weighted avg      0.545     0.546     0.542       970
#
# Saved results to outputs/best_model_taskC_bert-base-uncased_lr2e-5_bs16/results.json
# Backing up outputs/best_model_taskC_bert-base-uncased_lr2e-5_bs16 to Drive...
# Done backing up lr2e-5_bs16.
#
# Device: cuda
# Task C: train=3398 dev=486 test=970 | labels=['1.1 threats of harm', '1.2 incitement and encouragement of harm', '2.1 descriptive attacks', '2.2 aggressive and emotive attacks', '2.3 dehumanising attacks & overt sexual objectification', '3.1 casual use of gendered slurs, profanities, and insults', '3.2 immutable gender differences and gender stereotypes', '3.3 backhanded gendered compliments', '3.4 condescending explanations or unwelcome advice', '4.1 supporting mistreatment of individual women', '4.2 supporting systemic discrimination against women as a group']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 914.85it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [5.516233921051025, 1.2161775827407837, 0.4308355450630188, 0.45900312066078186, 1.5445454120635986, 0.4849436283111572, 0.7407891750335693, 4.826704502105713, 6.572534084320068, 4.11878776550293, 1.1973220109939575]
# Epoch 1/20 | train_loss=2.4278 | dev_macro_f1=0.0751
# Writing model shards: 100% 1/1 [00:16<00:00, 16.91s/it]
# Epoch 2/20 | train_loss=2.2046 | dev_macro_f1=0.2874
# Writing model shards: 100% 1/1 [00:16<00:00, 16.48s/it]
# Epoch 3/20 | train_loss=1.6899 | dev_macro_f1=0.4005
# Writing model shards: 100% 1/1 [00:37<00:00, 37.27s/it]
# Epoch 4/20 | train_loss=1.2394 | dev_macro_f1=0.3956
# Epoch 5/20 | train_loss=0.8719 | dev_macro_f1=0.4667
# Writing model shards: 100% 1/1 [00:13<00:00, 13.14s/it]
# Epoch 6/20 | train_loss=0.5611 | dev_macro_f1=0.4693
# Writing model shards: 100% 1/1 [00:12<00:00, 12.90s/it]
# Epoch 7/20 | train_loss=0.3772 | dev_macro_f1=0.4409
# Epoch 8/20 | train_loss=0.2567 | dev_macro_f1=0.4216
# Epoch 9/20 | train_loss=0.1590 | dev_macro_f1=0.4259
# Early stopping at epoch 9 (best dev macro-F1=0.4693 @ epoch 6)
#
# Loading best checkpoint (dev macro-F1=0.4693) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 15597.40it/s]
# Test macro-F1: 0.4230
#
#                                                                  precision    recall  f1-score   support
#
#                                             1.1 threats of harm      0.471     0.500     0.485        16
#                        1.2 incitement and encouragement of harm      0.474     0.753     0.582        73
#                                         2.1 descriptive attacks      0.555     0.444     0.493       205
#                              2.2 aggressive and emotive attacks      0.566     0.490     0.525       192
#         2.3 dehumanising attacks & overt sexual objectification      0.387     0.509     0.439        57
#      3.1 casual use of gendered slurs, profanities, and insults      0.638     0.610     0.624       182
#         3.2 immutable gender differences and gender stereotypes      0.537     0.487     0.511       119
#                             3.3 backhanded gendered compliments      0.167     0.111     0.133        18
#              3.4 condescending explanations or unwelcome advice      0.091     0.071     0.080        14
#                 4.1 supporting mistreatment of individual women      0.333     0.286     0.308        21
# 4.2 supporting systemic discrimination against women as a group      0.394     0.589     0.473        73
#
#                                                        accuracy                          0.513       970
#                                                       macro avg      0.419     0.441     0.423       970
#                                                    weighted avg      0.522     0.513     0.511       970
#
# Saved results to outputs/best_model_taskC_bert-base-uncased_lr2e-5_bs32/results.json
# Backing up outputs/best_model_taskC_bert-base-uncased_lr2e-5_bs32 to Drive...
# Done backing up lr2e-5_bs32.
#
# Device: cuda
# Task C: train=3398 dev=486 test=970 | labels=['1.1 threats of harm', '1.2 incitement and encouragement of harm', '2.1 descriptive attacks', '2.2 aggressive and emotive attacks', '2.3 dehumanising attacks & overt sexual objectification', '3.1 casual use of gendered slurs, profanities, and insults', '3.2 immutable gender differences and gender stereotypes', '3.3 backhanded gendered compliments', '3.4 condescending explanations or unwelcome advice', '4.1 supporting mistreatment of individual women', '4.2 supporting systemic discrimination against women as a group']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 7114.99it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [5.516233921051025, 1.2161775827407837, 0.4308355450630188, 0.45900312066078186, 1.5445454120635986, 0.4849436283111572, 0.7407891750335693, 4.826704502105713, 6.572534084320068, 4.11878776550293, 1.1973220109939575]
# Epoch 1/20 | train_loss=2.3927 | dev_macro_f1=0.1433
# Writing model shards: 100% 1/1 [00:04<00:00,  4.11s/it]
# Epoch 2/20 | train_loss=1.9138 | dev_macro_f1=0.3425
# Writing model shards: 100% 1/1 [00:21<00:00, 21.95s/it]
# Epoch 3/20 | train_loss=1.2667 | dev_macro_f1=0.4478
# Writing model shards: 100% 1/1 [00:21<00:00, 21.61s/it]
# Epoch 4/20 | train_loss=0.7112 | dev_macro_f1=0.4650
# Writing model shards: 100% 1/1 [00:11<00:00, 11.11s/it]
# Epoch 5/20 | train_loss=0.3692 | dev_macro_f1=0.4612
# Epoch 6/20 | train_loss=0.1772 | dev_macro_f1=0.4039
# Epoch 7/20 | train_loss=0.0870 | dev_macro_f1=0.4050
# Early stopping at epoch 7 (best dev macro-F1=0.4650 @ epoch 4)
#
# Loading best checkpoint (dev macro-F1=0.4650) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 6174.74it/s]
# Test macro-F1: 0.4142
#
#                                                                  precision    recall  f1-score   support
#
#                                             1.1 threats of harm      0.400     0.500     0.444        16
#                        1.2 incitement and encouragement of harm      0.500     0.644     0.563        73
#                                         2.1 descriptive attacks      0.518     0.561     0.539       205
#                              2.2 aggressive and emotive attacks      0.462     0.375     0.414       192
#         2.3 dehumanising attacks & overt sexual objectification      0.480     0.421     0.449        57
#      3.1 casual use of gendered slurs, profanities, and insults      0.577     0.615     0.596       182
#         3.2 immutable gender differences and gender stereotypes      0.538     0.294     0.380       119
#                             3.3 backhanded gendered compliments      0.222     0.111     0.148        18
#              3.4 condescending explanations or unwelcome advice      0.062     0.143     0.087        14
#                 4.1 supporting mistreatment of individual women      0.450     0.429     0.439        21
# 4.2 supporting systemic discrimination against women as a group      0.417     0.616     0.497        73
#
#                                                        accuracy                          0.486       970
#                                                       macro avg      0.421     0.428     0.414       970
#                                                    weighted avg      0.494     0.486     0.481       970
#
# Saved results to outputs/best_model_taskC_bert-base-uncased_lr3e-5_bs16/results.json
# Backing up outputs/best_model_taskC_bert-base-uncased_lr3e-5_bs16 to Drive...
# Done backing up lr3e-5_bs16.
#
# Device: cuda
# Task C: train=3398 dev=486 test=970 | labels=['1.1 threats of harm', '1.2 incitement and encouragement of harm', '2.1 descriptive attacks', '2.2 aggressive and emotive attacks', '2.3 dehumanising attacks & overt sexual objectification', '3.1 casual use of gendered slurs, profanities, and insults', '3.2 immutable gender differences and gender stereotypes', '3.3 backhanded gendered compliments', '3.4 condescending explanations or unwelcome advice', '4.1 supporting mistreatment of individual women', '4.2 supporting systemic discrimination against women as a group']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 6571.40it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [5.516233921051025, 1.2161775827407837, 0.4308355450630188, 0.45900312066078186, 1.5445454120635986, 0.4849436283111572, 0.7407891750335693, 4.826704502105713, 6.572534084320068, 4.11878776550293, 1.1973220109939575]
# Epoch 1/20 | train_loss=2.4158 | dev_macro_f1=0.1098
# Writing model shards: 100% 1/1 [00:42<00:00, 42.70s/it]
# Epoch 2/20 | train_loss=2.0511 | dev_macro_f1=0.3654
# Writing model shards: 100% 1/1 [00:07<00:00,  7.00s/it]
# Epoch 3/20 | train_loss=1.4206 | dev_macro_f1=0.4274
# Writing model shards: 100% 1/1 [00:06<00:00,  6.73s/it]
# Epoch 4/20 | train_loss=0.8963 | dev_macro_f1=0.4504
# Writing model shards: 100% 1/1 [00:47<00:00, 47.30s/it]
# Epoch 5/20 | train_loss=0.5338 | dev_macro_f1=0.4501
# Epoch 6/20 | train_loss=0.2971 | dev_macro_f1=0.4424
# Epoch 7/20 | train_loss=0.1677 | dev_macro_f1=0.4311
# Early stopping at epoch 7 (best dev macro-F1=0.4504 @ epoch 4)
#
# Loading best checkpoint (dev macro-F1=0.4504) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 19562.26it/s]
# Test macro-F1: 0.3631
#
#                                                                  precision    recall  f1-score   support
#
#                                             1.1 threats of harm      0.348     0.500     0.410        16
#                        1.2 incitement and encouragement of harm      0.377     0.753     0.502        73
#                                         2.1 descriptive attacks      0.545     0.322     0.405       205
#                              2.2 aggressive and emotive attacks      0.530     0.318     0.397       192
#         2.3 dehumanising attacks & overt sexual objectification      0.429     0.211     0.282        57
#      3.1 casual use of gendered slurs, profanities, and insults      0.560     0.670     0.610       182
#         3.2 immutable gender differences and gender stereotypes      0.564     0.370     0.447       119
#                             3.3 backhanded gendered compliments      0.214     0.167     0.188        18
#              3.4 condescending explanations or unwelcome advice      0.000     0.000     0.000        14
#                 4.1 supporting mistreatment of individual women      0.286     0.381     0.327        21
# 4.2 supporting systemic discrimination against women as a group      0.304     0.712     0.426        73
#
#                                                        accuracy                          0.444       970
#                                                       macro avg      0.378     0.400     0.363       970
#                                                    weighted avg      0.487     0.444     0.437       970
#
# Saved results to outputs/best_model_taskC_bert-base-uncased_lr3e-5_bs32/results.json
# Backing up outputs/best_model_taskC_bert-base-uncased_lr3e-5_bs32 to Drive...
# Done backing up lr3e-5_bs32.

# %%
# !python -m src.train --task C --model_name roberta-base --lr 3e-5 --batch_size 16 --epochs 20
# !python -m src.train --task C --model_name bert-base-uncased --lr 2e-5 --batch_size 16 --epochs 20
# Out:
# Device: cuda
# Task C: train=3398 dev=486 test=970 | labels=['1.1 threats of harm', '1.2 incitement and encouragement of harm', '2.1 descriptive attacks', '2.2 aggressive and emotive attacks', '2.3 dehumanising attacks & overt sexual objectification', '3.1 casual use of gendered slurs, profanities, and insults', '3.2 immutable gender differences and gender stereotypes', '3.3 backhanded gendered compliments', '3.4 condescending explanations or unwelcome advice', '4.1 supporting mistreatment of individual women', '4.2 supporting systemic discrimination against women as a group']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 197/197 [00:00<00:00, 2548.52it/s]
# [transformers] RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                        | Status     |
# ---------------------------+------------+-
# lm_head.dense.bias         | UNEXPECTED |
# lm_head.bias               | UNEXPECTED |
# lm_head.layer_norm.bias    | UNEXPECTED |
# lm_head.layer_norm.weight  | UNEXPECTED |
# lm_head.dense.weight       | UNEXPECTED |
# classifier.dense.weight    | MISSING    |
# classifier.dense.bias      | MISSING    |
# classifier.out_proj.weight | MISSING    |
# classifier.out_proj.bias   | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [5.516233921051025, 1.2161775827407837, 0.4308355450630188, 0.45900312066078186, 1.5445454120635986, 0.4849436283111572, 0.7407891750335693, 4.826704502105713, 6.572534084320068, 4.11878776550293, 1.1973220109939575]
# Epoch 1/20 | train_loss=2.3680 | dev_macro_f1=0.1454
# Writing model shards: 100% 1/1 [00:03<00:00,  3.51s/it]
# Epoch 2/20 | train_loss=1.9323 | dev_macro_f1=0.2717
# Writing model shards: 100% 1/1 [00:23<00:00, 23.83s/it]
# Epoch 3/20 | train_loss=1.4527 | dev_macro_f1=0.3812
# Writing model shards: 100% 1/1 [00:47<00:00, 47.20s/it]
# Epoch 4/20 | train_loss=1.0569 | dev_macro_f1=0.4130
# Writing model shards: 100% 1/1 [00:06<00:00,  6.79s/it]
# Epoch 5/20 | train_loss=0.6987 | dev_macro_f1=0.3938
# Epoch 6/20 | train_loss=0.4986 | dev_macro_f1=0.4482
# Writing model shards: 100% 1/1 [00:14<00:00, 14.14s/it]
# Epoch 7/20 | train_loss=0.3359 | dev_macro_f1=0.4269
# Epoch 8/20 | train_loss=0.2497 | dev_macro_f1=0.4152
# Epoch 9/20 | train_loss=0.1783 | dev_macro_f1=0.4290
# Early stopping at epoch 9 (best dev macro-F1=0.4482 @ epoch 6)
#
# Loading best checkpoint (dev macro-F1=0.4482) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 17204.50it/s]
# Test macro-F1: 0.4644
#
#                                                                  precision    recall  f1-score   support
#
#                                             1.1 threats of harm      0.615     0.500     0.552        16
#                        1.2 incitement and encouragement of harm      0.625     0.616     0.621        73
#                                         2.1 descriptive attacks      0.540     0.459     0.496       205
#                              2.2 aggressive and emotive attacks      0.470     0.656     0.548       192
#         2.3 dehumanising attacks & overt sexual objectification      0.448     0.526     0.484        57
#      3.1 casual use of gendered slurs, profanities, and insults      0.728     0.500     0.593       182
#         3.2 immutable gender differences and gender stereotypes      0.481     0.420     0.448       119
#                             3.3 backhanded gendered compliments      0.500     0.167     0.250        18
#              3.4 condescending explanations or unwelcome advice      0.074     0.143     0.098        14
#                 4.1 supporting mistreatment of individual women      0.462     0.571     0.511        21
# 4.2 supporting systemic discrimination against women as a group      0.466     0.562     0.509        73
#
#                                                        accuracy                          0.518       970
#                                                       macro avg      0.492     0.465     0.464       970
#                                                    weighted avg      0.542     0.518     0.519       970
#
# Saved results to outputs/best_model_taskC_roberta-base/results.json
# Device: cuda
# Task C: train=3398 dev=486 test=970 | labels=['1.1 threats of harm', '1.2 incitement and encouragement of harm', '2.1 descriptive attacks', '2.2 aggressive and emotive attacks', '2.3 dehumanising attacks & overt sexual objectification', '3.1 casual use of gendered slurs, profanities, and insults', '3.2 immutable gender differences and gender stereotypes', '3.3 backhanded gendered compliments', '3.4 condescending explanations or unwelcome advice', '4.1 supporting mistreatment of individual women', '4.2 supporting systemic discrimination against women as a group']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 5363.15it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Class weights: [5.516233921051025, 1.2161775827407837, 0.4308355450630188, 0.45900312066078186, 1.5445454120635986, 0.4849436283111572, 0.7407891750335693, 4.826704502105713, 6.572534084320068, 4.11878776550293, 1.1973220109939575]
# Epoch 1/20 | train_loss=2.4144 | dev_macro_f1=0.1082
# Writing model shards: 100% 1/1 [00:38<00:00, 38.60s/it]
# Epoch 2/20 | train_loss=2.0683 | dev_macro_f1=0.3333
# Writing model shards: 100% 1/1 [00:11<00:00, 11.55s/it]
# Epoch 3/20 | train_loss=1.4722 | dev_macro_f1=0.4280
# Writing model shards: 100% 1/1 [00:37<00:00, 37.85s/it]
# Epoch 4/20 | train_loss=0.9601 | dev_macro_f1=0.4419
# Writing model shards: 100% 1/1 [00:07<00:00,  7.46s/it]
# Epoch 5/20 | train_loss=0.5690 | dev_macro_f1=0.4669
# Writing model shards: 100% 1/1 [00:21<00:00, 21.70s/it]
# Epoch 6/20 | train_loss=0.3194 | dev_macro_f1=0.4732
# Writing model shards: 100% 1/1 [00:12<00:00, 12.84s/it]
# Epoch 7/20 | train_loss=0.1741 | dev_macro_f1=0.4468
# Epoch 8/20 | train_loss=0.0880 | dev_macro_f1=0.4219
# Epoch 9/20 | train_loss=0.0476 | dev_macro_f1=0.4027
# Early stopping at epoch 9 (best dev macro-F1=0.4732 @ epoch 6)
#
# Loading best checkpoint (dev macro-F1=0.4732) for final test evaluation...
# Loading weights: 100% 201/201 [00:00<00:00, 5853.33it/s]
# Test macro-F1: 0.4385
#
#                                                                  precision    recall  f1-score   support
#
#                                             1.1 threats of harm      0.545     0.375     0.444        16
#                        1.2 incitement and encouragement of harm      0.568     0.740     0.643        73
#                                         2.1 descriptive attacks      0.560     0.546     0.553       205
#                              2.2 aggressive and emotive attacks      0.515     0.620     0.563       192
#         2.3 dehumanising attacks & overt sexual objectification      0.467     0.491     0.479        57
#      3.1 casual use of gendered slurs, profanities, and insults      0.692     0.544     0.609       182
#         3.2 immutable gender differences and gender stereotypes      0.537     0.546     0.542       119
#                             3.3 backhanded gendered compliments      0.231     0.167     0.194        18
#              3.4 condescending explanations or unwelcome advice      0.000     0.000     0.000        14
#                 4.1 supporting mistreatment of individual women      0.333     0.238     0.278        21
# 4.2 supporting systemic discrimination against women as a group      0.506     0.534     0.520        73
#
#                                                        accuracy                          0.546       970
#                                                       macro avg      0.451     0.436     0.439       970
#                                                    weighted avg      0.545     0.546     0.542       970
#
# Saved results to outputs/best_model_taskC_bert-base-uncased/results.json
